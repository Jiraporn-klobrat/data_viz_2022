# %% [markdown]
# <a href="https://colab.research.google.com/github/Jiraporn-klobrat/data_viz_2022/blob/main/Pandas101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd    # pandas เป็น Package ที่ใช้เกี่ยวกับการจัดการข้อมูลที่เป็นตาราง , เรียกใช้โดยการ import แล้วตามด้วยชื่อ Package

# %% [markdown]
# .csv = Comma Separated Values

# %% [markdown]
# data.go.th

# %%
from google.colab import drive    # เชื่อมต่อกับ google drive ที่เราเก็บข้อมูลไว้
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os    # เป็น package ที่เอาไว้จัดการไฟล์และเอาไว้ดูที่มาของไฟล์หรือ path

# %%
path = '/content/drive/My Drive/dataviz_2022_data'    #ระบุให้ชี้ไปที่โฟลเดอร์ใน google drive ที่เราเซฟไฟล์ไว้ คือ โฟลเดอร์ dataviz_2022_data

# %%
covid_file_path = os.path.join(path,'pm-20-jan-2021.csv')    # ไฟล์ที่เราต้องการ
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2022_data/pm-20-jan-2021.csv

# %%
a = path + '/pm-18-jan-2021.csv' 
print(a)
# Out:
# /content/drive/My Drive/dataviz_2022_data/pm-18-jan-2021.csv

# %% [markdown]
# ## Load data to memory

# %%
data_covid = pd.read_csv(covid_file_path) # ไฟล์ที่เราต้องการ
data_covid    # print data ออกมาดูว่ามันหน้าตาเป็นยังไง
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_covid.shape
# Out:
# (12653, 10)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# ### basic

# %%
data_covid['province_of_onset']
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset'][4]
# Out:
# 'กรุงเทพมหานคร'

# %%
data_covid['risk'][12649]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %% [markdown]
# ### .iloc

# %%
data_covid.iloc[4,7]
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# ### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = data_covid[['announce_date','province_of_onset','risk']]
smaller_table
# Out:
#       announce_date  ...                                         risk
# 0         1/12/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         1/17/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         1/22/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         1/22/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         1/24/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...             ...  ...                                          ...
# 12648     1/20/2021  ...                             State Quarantine
# 12649     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651     1/20/2021  ...                                Cluster ระยอง
# 12652     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 3 columns]

# %% [markdown]
# ### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# #### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# $pddf$[list_of_logical_values] คือการเลือก row ที่ logocal values เป็น true

# %%
data_covid['province_of_onset']    # เลือก row ที่เราต้องการ
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset']=='ขอนแก่น'    # เลือก row ที่เราต้องการและเลือกค่าเท่ากับขอนแก่น #list นี้จะมีจำนวนเท่ากับจำนวนแถวของdata
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']    # เลือกเฉพาะ row ที่ค่า province เป็น true ได้เฉพาะข้อมูลของขอนแก่น
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
data_covid[data_covid['age']>=70]    #ดูข้อมูลของคนที่อายุมากกว่าเท่ากับ70
# Out:
#          No.  ...                                               risk
# 1          2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7          8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 24        25  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 82        83  ...                                            สนามมวย
# ...      ...  ...                                                ...
# 11694  11695  ...      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 11700  11701  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11730  11731  ...                                  Cluster สมุทรสาคร
# 11741  11742  ...                               อยู่ระหว่างการสอบสวน
# 12102  12103  ...                                  Cluster สมุทรสาคร
#
# [245 rows x 10 columns]

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,:] # ตารางตัวอย่าง data แค่ 8 ตัวแรก #เอาตั้งแต่ตัวแรกจนที่ตัวที่8และเอาคอลัมน์ที่3เป็นต้นไป
eight_rows_covid
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7    8     1/26/2020  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 10 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ list ที่มีค่า logic ของ rows แต่ละ row โดยที่ค่า true คือเอา และ ค่า false คือ ไม่เอา
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression 
# ดูว่าค่าไหนในคอลัมน์ province_of_onset เป็นกรุงเทพบ้างถ้าเป็นกรุงเทพจะแสดงค่า true
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']   #เราเอา 2 บรรทัดบนมาบวกกัน
# เป็นการเลือกเฉพาะ row ที่มีค่าที่เราต้องการ
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 10 columns]

# %%
eight_rows_covid['district_of_onset']=='เมือง'
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: district_of_onset, dtype: bool

# %% [markdown]
# $.isnull()$ใช้ตรวจสอบว่าเป็น NaN หรือไม่

# %%
eight_rows_covid['district_of_onset'].isnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: district_of_onset, dtype: bool

# %% [markdown]
# ## Quiz (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1. คำนวณ อายุเฉลี่ย ของผู้ชาย ในข้อมูลทั้งหมด
# 2. คำนวณ อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น
# 3. หาจำนวนผู้ป่วยที่เป็นคน ที่ไม่ใช่คนไทย

# %%
this_data = data_covid[['sex','age','province_of_onset']]    # กำหนดัวแปรชื่อ this_data1 เพื่อเก็บข้อมูล data_covid ที่เลือกมาเฉพาะข้อมูล sex,age,province_of_onset(เพศ,อายุ,จังหวัด)
this_data    # แสดงตารางที่ชื่อ this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
this_data_1 = data_covid[['sex','age','province_of_onset']]   # กำหนดัวแปรชื่อ this_data1 เพื่อเก็บข้อมูล data_covid ที่เลือกมาเฉพาะข้อมูล sex,age,province_of_onset(เพศ,อายุ,จังหวัด)
this_data_1    # แสดงตารางที่ชื่อ this_data1
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
#1. คำนวณ อายุเฉลี่ย ของ**ผู้ชาย** ของข้อมูลทั้งหมด
male = this_data_1[this_data_1['sex']=='ชาย']    # เลือกเฉพาะเพศชาย กำหนดให้ 'sex' == 'ชาย' โดยเลือกจากตาราง this_data แล้วเอาไปใส่ในตารางที่ชื่อว่า male
male # เรียกแสดงตารางชื่อ male
#male['age']
# Out:
#        sex   age province_of_onset
# 3      ชาย  68.0     กรุงเทพมหานคร
# 8      ชาย  63.0     กรุงเทพมหานคร
# 10     ชาย  33.0     กรุงเทพมหานคร
# 11     ชาย  61.0     กรุงเทพมหานคร
# 12     ชาย   6.0     กรุงเทพมหานคร
# ...    ...   ...               ...
# 12640  ชาย  66.0   พระนครศรีอยุธยา
# 12641  ชาย  29.0          ปทุมธานี
# 12643  ชาย  39.0              สตูล
# 12646  ชาย  18.0       สมุทรปราการ
# 12647  ชาย  42.0     กรุงเทพมหานคร
#
# [4819 rows x 3 columns]

# %%
male['age'] # แสดงตารางข้อมูลของ male คอลัมน์ 'age'
# Out:
# 3        68.0
# 8        63.0
# 10       33.0
# 11       61.0
# 12        6.0
#          ...
# 12640    66.0
# 12641    29.0
# 12643    39.0
# 12646    18.0
# 12647    42.0
# Name: age, Length: 4819, dtype: float64

# %%
# สามารถคำนวณอายุเฉลี่ยของผู้ชาย ในข้อมูลทั้งหมด ได้ดังนี้
sum = 0 # กำหนดให้ sum = 0 เนื่องจากถ้าค่าตัวที่ 1 เข้ามาบวกจะได้ค่าออกมาเท่ากับตัวที่ 1
N = 0 # กำหนดให้ N = 0 เนื่องจาก N เป็นตัวหาร โดยจะทำการวนลูป (N เป็นตัวแปรที่จะนับว่ามีคนทั้งหมดกี่คน)
for a in male['age']: # เริ่มวนลูปโดยให้ a แทนค่าแต่ละค่าในคอลัมน์ 'age' ของตารางที่มีชื่อว่า male  
    if a > 0: # ถ้า a มากกว่า 0 แสดงว่าเป็นอายุปกติ ไม่ใช่ข้อมูลที่ผิดพลาด 
        sum += a # sum = sum + a คือ ถ้า a > 0 จะนำมารวมเข้าไปใน sum เรื่อย ๆ ในทุก ๆ รอบที่ a มากกว่า 0
        N += 1 # คำนวนจำนวนโดยที่มันจะ +1 เข้ามาเรื่อย ๆ ตามจำนวน
        # sum คือ ค่าของผลรวมของอายุทั้งหมด  N คือ ค่าของจำนวนคนทั้งหมด
print(f'อายุเฉลี่ยของผู้ป่วยชาย เท่ากับ {sum/N} ปี') # sum/N = อายุเฉลี่ยของผู้ชายในข้อมูลทั้งหมด
# จะได้ว่า อายุเฉลี่ยของผู้ป่วยชาย เท่ากับ 39.46076940331987 ปี
# Out:
# อายุเฉลี่ยของผู้ป่วยชาย เท่ากับ 39.46076940331987 ปี

# %%
male_KhonKaen = male[male['province_of_onset']=='ขอนแก่น']  #เลือกเฉพาะจังหวัดขอนแก่น เลือกจากตารางที่ชื่อว่า male โดยสนใจคอลัมน์ที่ชื่อว่า province_of_onset แล้วเอาไปใส่ในตัวแปรชื่อ male_KhonKaen
male_KhonKaen # เรียกดูข้อมูลในตารางที่ชื่อว่า male_KhonKaen
# Out:
#        sex   age province_of_onset
# 180    ชาย  33.0           ขอนแก่น
# 1466   ชาย  19.0           ขอนแก่น
# 2673   ชาย  68.0           ขอนแก่น
# 9333   ชาย  17.0           ขอนแก่น
# 9334   ชาย  20.0           ขอนแก่น
# 10610  ชาย  17.0           ขอนแก่น
# 11517  ชาย  12.0           ขอนแก่น

# %%
#สามารถคำนวณอายุเฉลี่ยของผู้ชายในจังหวัดขอนแก่น ได้ดังนี้
sum = 0 # กำหนดให้ sum = 0 เนื่องจากถ้าค่าตัวที่ 1 เข้ามาบวกจะได้ค่าออกมาเท่ากับตัวที่ 1
N = 0 # กำหนดให้ N = 0 เนื่องจาก N เป็นตัวหาร โดยจะทำการวนลูป (N เป็นตัวแปรที่จะนับว่ามีคนทั้งหมดกี่คน)
for a in male_KhonKaen['age']: #เริ่มวนลูปโดยให้ a แทนค่าแต่ละค่าในคอมลัมน์ 'age' ของตารางที่มีชื่อว่า male_KhonKaen 
    if a > 0: # ถ้า a มากกว่า 0 แสดงว่าเป็นอายุปกติ ไม่ใช่ข้อมูลที่ผิดพลาด 
        sum += a # sum = sum + a คือ ถ้า a > 0 จะนำมารวมเข้าไปใน sum เรื่อย ๆ ในทุก ๆ รอบที่ a มากกว่า 0
        N += 1 # คำนวนจำนวนโดยที่มันจะ +1 เข้ามาเรื่อย ๆ ตามจำนวน
        # sum คือ ค่าของผลรวมของอายุทั้งหมด  N คือ ค่าของจำนวนคนทั้งหมด
print(f'อายุเฉลี่ยของผู้ป่วยชายในจังหวัดขอนแก่น เท่ากับ {sum/N} ปี') # sum/N = อายุเฉลี่ยของผู้ชายในจังหวัดขอนแก่น
# จะได้ว่า อายุเฉลี่ยของผู้ป่วยชายในจังหวัดขอนแก่น เท่ากับ 26.571428571428573 ปี
# Out:
# อายุเฉลี่ยของผู้ป่วยชายในจังหวัดขอนแก่น เท่ากับ 26.571428571428573 ปี

# %%
#3. หาจำนวนผู้ป่วยที่เป็นคน "ที่ไม่ใช่คนไทย"
this_data2 = data_covid[['sex','age','nationality']] # กำหนดัวแปรชื่อ this_data2 เพื่อเก็บข้อมูล data_covid ที่เลือกมาเฉพาะข้อมูล sex,age,province_of_onset(เพศ,อายุ,จังหวัด)
this_data2 # แสดงตารางที่ชื่อ this_data2
# Out:
#         sex   age nationality
# 0      หญิง  61.0       China
# 1      หญิง  74.0       China
# 2      หญิง  73.0    Thailand
# 3       ชาย  68.0       China
# 4      หญิง  66.0       China
# ...     ...   ...         ...
# 12648  หญิง  44.0    Thailand
# 12649  หญิง  52.0    Thailand
# 12650  หญิง  23.0    Thailand
# 12651  หญิง  29.0    Thailand
# 12652  หญิง  22.0       Burma
#
# [12653 rows x 3 columns]

# %%
foreigner = this_data2[this_data2['nationality']!='Thailand'] #เลือกเฉพาะที่ไม่ใช่ประเทศไทย เลือกจากตารางที่ชื่อว่า this_data2 โดยสนใจคอลัมน์ที่ชื่อว่า nationality(สัญชาติ) แล้วเอาไปใส่ในตัวแปรชื่อ foreigner(ชาวต่างชาติ)
foreigner #แสดงตารางที่ชื่อ foreigner
# Out:
#         sex   age nationality
# 0      หญิง  61.0       China
# 1      หญิง  74.0       China
# 3       ชาย  68.0       China
# 4      หญิง  66.0       China
# 5      หญิง  33.0       China
# ...     ...   ...         ...
# 12614  หญิง  43.0       Burma
# 12615  หญิง  35.0       Burma
# 12617  หญิง  12.0     Ireland
# 12618  หญิง  34.0    Pakistan
# 12652  หญิง  22.0       Burma
#
# [5340 rows x 3 columns]

# %%
foreigner.count() # ใช้คำสั่ง .count() เพื่อดูจำนวน
# Out:
# sex            2889
# age            2038
# nationality    4129
# dtype: int64

# %%
this_data = data_covid[['sex','age','province_of_onset']] #เลือกเฉพาะคอลัมนืทีต้องการ ได้แก่ 'sex','age','province_of_onset'

# %%
this_data #แสดงตาราง
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง'] # เลือกเฉพาะเพศหญิง เลือกจากตารางที่ชื่อว่าthis_dataโดยสนใจคอลัมน์ที่ชื่อว่า sex แล้วเอาไปใส่ในตารางที่ชื่อว่า female
female['age'] # เลือกดูเฉพาะอายุในตาราง female
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 5332, dtype: float64

# %%
# หาค่าเฉลี่ยของอายุได้โดย
sum = 0 # กำหนดให้ sum = 0 เนื่องจากถ้าค่าตัวที่ 1 มาบวกจะได้ค่าออกมาเท่ากับตัวที่ 1
N = 0 # กำหนดให้ N = 0 เป็นตัวหาร โดยจะทำการวนลูป # N เป็นตัวแปรที่จะนับว่ามีคนทั้งหมดกี่คน 
for a in female['age']: #เริ่มวนลูปโดยใน a แทนค่าแต่ละค่าในคอมลัมน์ age ของตาราง female
    
    if a > 0: # ถ้า a มากกว่า 0 แสดงว่าเป็นอายุปกติที่ไม่ใช่ข้อมูลที่ผิดพลาด
        sum += a # sum = sum + a # ถ้า a > 0 ก็จะนำมารวมเข้าไปใน sum เลื่อยๆในทุกๆรอบที่ a มากกว่า 0
        N += 1 # คำนวนจำนวนโดยที่มันจะ +1 เข้ามาเลื่อยๆ
        # sum คือค่าผลรวมทั้งหมด  N คือค่าจำนวนคนทั้งหมด
print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}') # sum/N = หาอายุเฉลี่ยของคนทั้งหมด
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.63955450022614

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น'] # เลือกเฉพาะจังหวัดขอนแก่น

sum = 0
N = 0
for a in female_KK['age']:
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %% [markdown]
# 14/01/65

# %% [markdown]
# ## เฉลย Quiz (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1. คำนวณ อายุเฉลี่ย ของผู้ชาย ในข้อมูลทั้งหมด
# 2. คำนวณ อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น
# 3. หาจำนวนผู้ป่วยที่เป็นคน ที่ไม่ใช่คนไทย

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']
female
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 4      หญิง  66.0     กรุงเทพมหานคร
# 5      หญิง  33.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [5332 rows x 3 columns]

# %%
female['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 5332, dtype: float64

# %%
sum = 0   
N = 0
for a in female['age']:
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.63955450022614

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0 
N = 0
for a in female_KK['age']:
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %%
female[(female['province_of_onset']=='ขอนแก่น') | (female['province_of_onset']=='หนองคาย')]
# Out:
#         sex   age province_of_onset
# 462    หญิง  36.0           ขอนแก่น
# 1051   หญิง  30.0           หนองคาย
# 1970   หญิง  70.0           ขอนแก่น
# 2637   หญิง  63.0           ขอนแก่น
# 5948   หญิง  32.0           ขอนแก่น
# 6082   หญิง  36.0           ขอนแก่น
# 10834  หญิง  40.0           หนองคาย
# 11697  หญิง  17.0           ขอนแก่น
# 11698  หญิง  37.0           ขอนแก่น

# %%
# หาจำนวนคนป่วยที่ไม่ใช่คนไทย
import numpy as np

# %%
np.sum(data_covid['nationality'].dropna() != 'Thailand')
# Out:
# 4129

# %% [markdown]
# ## การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data.head()    #เช็คว่า this_data คืออะไร หน้าตาเป็นยังไง
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
this_data.shape #(12423, 3)     # ดูขนาด
# Out:
# (12653, 3)

# %%
this_data.dropna()    # ตัดค่า missing
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8478 rows x 3 columns]

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)
# Out:
# (12653, 10)
# (6655, 10)

# %%
this_data.dropna(subset=['age','sex'])
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8880 rows x 3 columns]

# %%
print(this_data.dropna().shape)
print(this_data.dropna(subset=['age','sex']).shape)
# Out:
# (8478, 3)
# (8880, 3)

# %% [markdown]
# ## ตรวจสอบ Missing (```isnull()```)

# %%
this_data.isnull()
# Out:
#          sex    age  province_of_onset
# 0      False  False              False
# 1      False  False              False
# 2      False  False              False
# 3      False  False              False
# 4      False  False              False
# ...      ...    ...                ...
# 12648  False  False              False
# 12649  False  False              False
# 12650  False  False              False
# 12651  False  False              False
# 12652  False  False              False
#
# [12653 rows x 3 columns]

# %%
this_data.isnull().any()     # .any() เอาค่าความจริงใน column มา OR กัน
# Out:
# sex                  True
# age                  True
# province_of_onset    True
# dtype: bool

# %%
this_data.isnull().all()     # .all() เอาค่าความจริงใน column มา AND กัน
# Out:
# sex                  False
# age                  False
# province_of_onset    False
# dtype: bool

# %%
this_data.isnull().any().any()
# Out:
# True

# %%
this_data.dropna(subset=['age','sex']).isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %%
this_data.dropna(subset=['age','sex'])
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8880 rows x 3 columns]

# %% [markdown]
# 1. เพื่อให้ได้ผลลัพธ์การจัดการ ```dropna()``` ต้องเอาตัวแปรมารับ

# %%
this_data_nonull = this_data.dropna(subset=['age','sex'])

# %%
this_data_nonull.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %% [markdown]
# 2. update ตารางด้วยตัวแปร ```inplace```

# %%
this_data.dropna(subset=['age','sex'],inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %%
aa = this_data.dropna(subset=['age','sex'],inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
aa    #ไม่ print แสดงว่าเป็นค่าว่าง

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna()```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 12653
# จำนวน record หลัง drop missing ใน province 10662

# %% [markdown]
# 1. แทนด้วย class ใหม่

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-1, 'province_of_onset':'ไม่รู้'})
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated.tail(15)
# Out:
#           sex   age province_of_onset
# 12638  ไม่รู้  -1.0         สมุทรสาคร
# 12639  ไม่รู้  -1.0         สมุทรสาคร
# 12640     ชาย  66.0   พระนครศรีอยุธยา
# 12641     ชาย  29.0          ปทุมธานี
# 12642    หญิง  50.0           ราชบุรี
# 12643     ชาย  39.0              สตูล
# 12644    หญิง  49.0       สมุทรปราการ
# 12645    หญิง  44.0            ชลบุรี
# 12646     ชาย  18.0       สมุทรปราการ
# 12647     ชาย  42.0     กรุงเทพมหานคร
# 12648    หญิง  44.0            ชลบุรี
# 12649    หญิง  52.0             ระยอง
# 12650    หญิง  23.0             ระยอง
# 12651    หญิง  29.0             ระยอง
# 12652    หญิง  22.0               ตาก

# %%
this_data_updated.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset    False
# dtype: bool

# %% [markdown]
# 2. แทนด้วยค่าที่เหมาะสม
# * ตามใจคนทำ
# * ค่ากลาง

# %% [markdown]
# ตามใจคนทำ

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_covid_fillasiwant = data_covid.fillna(value={'sex':'หญิง'})  #เรามีข้อมูลว่า เพศหญิงมีเยอะกว่าเพศชาย

# %%
data_covid_fillasiwant.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                      False
# age                       True
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# แทนด้วยค่ากลาง

# %%
data_covid['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 3        68.0
# 4        66.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 12653, dtype: float64

# %%
data_covid['age'].mean()
# Out:
# 38.054748339151

# %%
data_covid_fillwithmean = data_covid.fillna(value={'age':data_covid['age'].mean()})

# %%
data_covid_fillwithmean.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                       True
# age                      False
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# ### การวนลูป record ในตาราง (```.iterrows```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
for each_row in this_data.iterrows():
    # print(each_row)
    # print(each_row[1])
    # print(each_row[1]['sex'])
    if (each_row[1]['age'] <= 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):
        print(each_row)
# Out:
# (1466, sex                      ชาย
# age                       19
# province_of_onset    ขอนแก่น
# Name: 1466, dtype: object)
# (9333, sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 9333, dtype: object)
# (9334, sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object)
# (10610, sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 10610, dtype: object)
# (11517, sex                      ชาย
# age                       12
# province_of_onset    ขอนแก่น
# Name: 11517, dtype: object)
# (11697, sex                     หญิง
# age                       17
# province_of_onset    ขอนแก่น
# Name: 11697, dtype: object)

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array (```.iloc```)

# %%
for each_row in range(this_data.shape[0]):
    if (this_data.iloc[each_row,1] <= 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)
        print(this_data.iloc[each_row,:])
# Out:
# 1466
# sex                      ชาย
# age                       19
# province_of_onset    ขอนแก่น
# Name: 1466, dtype: object
# 9333
# sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 9333, dtype: object
# 9334
# sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object
# 10610
# sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 10610, dtype: object
# 11517
# sex                      ชาย
# age                       12
# province_of_onset    ขอนแก่น
# Name: 11517, dtype: object
# 11697
# sex                     หญิง
# age                       17
# province_of_onset    ขอนแก่น
# Name: 11697, dtype: object

# %% [markdown]
# ## Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
#
# **Hint**
# *   วนลูปหา index ของปี 2021
# *   ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
#        No.  ...                                               risk
# 6884  6885  ...                                  Cluster สมุทรสาคร
# 6885  6886  ...                                      Cluster ระยอง
# 6886  6887  ...                                        สถานบันเทิง
# 6887  6888  ...                                  Cluster สมุทรสาคร
# 6888  6889  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
#
# [5 rows x 10 columns]

# %% [markdown]
# ## HW กลุ่ม 2 || เลือกข้อมูลมาเฉพาะวัน announce_date เป็นวันที่ 1-20

# %%
data_covid    # รันหน้าตาของตาราง data_covid ออกมาดู
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %%
HW2=list()
for each_row in data_covid.iterrows():      #วนลูปหา index ของวันที่ 1-20
    if each_row[1]['announce_date'].split('/')[1] <= '20':     #ตัดตารางมาเฉพาะ วันที่ 1-20 ของ announce_date โดย .split('/')[1] <= '20':    # .split('/')[1] <= '20': หมายถึงว่าแบ่งstr ด้วย / และนับเอาตัวเลขที่อยู่ตำแหน่งที่ 1 มา โดยมีค่าน้อยกว่าหรือเท่ากับ 20
        HW2.append(True)   # ถ้าตารางมีวันที่ 1-20 ในช่องของ announce_date จะเลือกมา แล้วไปเริ่มวนลูปมาใหม่
    else:
        HW2.append(False)   # แต่ถ้าตารางไม่มีวันที่ 1-20 ในช่องของ announce_date จะไม่เลือกมา แล้วไปเริ่มวนลูปมาใหม่

data_covid[HW2]
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 32        33  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 33        34  ...              บุคลากรด้านการแพทย์และสาธารณสุข
# 34        35  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5135 rows x 10 columns]

# %%
# เฉลย HW กลุ่ม 2 || เลือกข้อมูลมาเฉพาะวัน announce_date เป็นวันที่ 1-20
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[1] <= '20':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
#     No.  ...                                         risk
# 0     1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1     2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 32   33  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 33   34  ...              บุคลากรด้านการแพทย์และสาธารณสุข
# 34   35  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 10 columns]

# %%
TF
# Out:
# [True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()
# Out:
#                 No.          age
# count  12653.000000  8881.000000
# mean    6327.000000    38.054748
# std     3652.750813    15.125178
# min        1.000000     0.100000
# 25%     3164.000000    27.000000
# 50%     6327.000000    36.000000
# 75%     9490.000000    48.000000
# max    12653.000000    97.000000

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()
# Out:
# 39.46076940331987

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
