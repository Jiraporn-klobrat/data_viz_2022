# %% [markdown]
# <a href="https://colab.research.google.com/github/Jiraporn-klobrat/data_viz_2022/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Present Project กลุ่ม
# ทำ Dashboard ของ Data Covid (ตั้งแต่วันที่ 12/01/2020 - 18/03/2022) เล่ามุมมองที่เราเลือกเอง + ใช้ข้อมูลภูมิภาค + ข้อมูลอื่นที่เลือกเอง
#
# เริ่มพรีเซ็นต์ 25 มีค 30 มีค 1 เมษา

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
path = '/content/drive/My Drive/Project_dataviz22'

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# คำอธิบาย
# * No	รหัสผู้ป่วย
# * Age	อายุของผู้ป่วย
# * Sex	เพศผู้ป่วย
# * Nationality	สัญชาติ
# * Province of isolation	จังหวัดที่รักษาตัว
# * Notification Date	วันที่กระทรวงได้รับรายงาน
# * Announce Date	วันที่แถลงข่าว
# * Province of onset		จังหวัดที่เริ่มพบว่าตัวเองมีอาการป่วย
# * District of onset		อำเภอที่เริ่มพบว่าตัวเองมีอาการป่วย
# * risk สถานที่

# %% [markdown]
# ## ตารางข้อมูล covid ปี2020

# %%
data_covid2020 =  pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_covid2020
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %% [markdown]
# ลบค่าว่างออกจากข้อมูล

# %%
data_covid2020 = data_covid2020.fillna(method="bfill")

# %%
data_covid20 = data_covid2020.dropna()
data_covid20
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020      4/3/2020  หญิง  61.0   ปี       China
# 1            2     17/1/2020      4/3/2020  หญิง  74.0   ปี       China
# 2            3     22/1/2020      4/3/2020  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020      4/3/2020   ชาย  68.0   ปี       China
# 4            5     24/1/2020      4/3/2020  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839391  839392     12/8/2021     11/8/2021  หญิง  83.0   ปี    Thailand
# 839392  839393     12/8/2021     11/8/2021   ชาย  66.0   ปี    Thailand
# 839393  839394     12/8/2021     11/8/2021  หญิง  43.0   ปี    Thailand
# 839394  839395     12/8/2021     11/8/2021  หญิง  74.0   ปี    Thailand
# 839395  839396     12/8/2021     11/8/2021   ชาย  29.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 839391         กรุงเทพมหานคร
# 839392         กรุงเทพมหานคร
# 839393         กรุงเทพมหานคร
# 839394         กรุงเทพมหานคร
# 839395         กรุงเทพมหานคร
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 839391      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 839392        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 839393      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 839394      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 839395  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
#
#        district_of_onset
# 0                  เมือง
# 1                  เมือง
# 2                  เมือง
# 3                 หัวหิน
# 4                 หัวหิน
# ...                  ...
# 839391             วัฒนา
# 839392       บางขุนเทียน
# 839393            ประเวศ
# 839394            ธนบุรี
# 839395            ประเวศ
#
# [839396 rows x 11 columns]

# %% [markdown]
# ## ตารางข้อมูล covid ปี2021(1)

# %%
data_covid2021_1 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-120864.csv'))
data_covid2021_1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ลบค่าว่างออกจากข้อมูล

# %%
data_covid21_1 = data_covid2021_1.dropna()
data_covid21_1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 249       817239     12/8/2021     11/8/2021   ชาย  48.0   ปี    Thailand
# 250       817240     12/8/2021     11/8/2021  หญิง  19.0   ปี    Thailand
# 251       817241     12/8/2021     11/8/2021  หญิง  37.0   ปี    Thailand
# 252       817242     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 253       817243     12/8/2021     11/8/2021   ชาย  60.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1041962  1858952    25/10/2021    24/10/2021   ชาย  67.0   ปี    Thailand
# 1041963  1858953    25/10/2021    24/10/2021  หญิง  39.0   ปี    Thailand
# 1041964  1858954    25/10/2021    24/10/2021   ชาย  80.0   ปี    Thailand
# 1041965  1858955    25/10/2021    24/10/2021  หญิง  67.0   ปี    Thailand
# 1041966  1858956    25/10/2021    24/10/2021  หญิง  53.0   ปี    Thailand
#
#         province_of_isolation                                         risk  \
# 249                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 250                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 251                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 252                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 253                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1041962         กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1041963         กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1041964         กรุงเทพมหานคร                                        อื่นๆ
# 1041965         กรุงเทพมหานคร                                        อื่นๆ
# 1041966         กรุงเทพมหานคร                                        อื่นๆ
#
#         province_of_onset district_of_onset
# 249             เพชรบูรณ์    เมืองเพชรบูรณ์
# 250             เพชรบูรณ์    เมืองเพชรบูรณ์
# 251             เพชรบูรณ์    เมืองเพชรบูรณ์
# 252             เพชรบูรณ์    เมืองเพชรบูรณ์
# 253             เพชรบูรณ์    เมืองเพชรบูรณ์
# ...                   ...               ...
# 1041962     กรุงเทพมหานคร           บางพลัด
# 1041963     กรุงเทพมหานคร           บางพลัด
# 1041964     กรุงเทพมหานคร            สายไหม
# 1041965     กรุงเทพมหานคร            สายไหม
# 1041966     กรุงเทพมหานคร            สายไหม
#
# [773368 rows x 11 columns]

# %% [markdown]
# ## ตารางข้อมูล covid ปี2021(2)

# %%
data_covid2021_2 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-271064.csv'))
data_covid2021_2
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454               NaN               NaN          NaN
# 1010455               NaN               NaN          NaN
# 1010456               NaN               NaN          NaN
# 1010457               NaN               NaN          NaN
# 1010458               NaN               NaN          NaN
#
# [1010459 rows x 12 columns]

# %% [markdown]
# ## ตารางข้อมูล covid ปี2022

# %%
data_covid2022 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-280265.csv'))
data_covid2022
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ## ต่อตาราง

# %%
covid = pd.concat([data_covid20,data_covid21_1,data_covid2021_2,data_covid2022])
covid
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020      4/3/2020  หญิง  61.0   ปี       China
# 1             2     17/1/2020      4/3/2020  หญิง  74.0   ปี       China
# 2             3     22/1/2020      4/3/2020  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020      4/3/2020   ชาย  68.0   ปี       China
# 4             5     24/1/2020      4/3/2020  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  Unnamed: 11
# 0          กรุงเทพมหานคร             เมือง          NaN
# 1          กรุงเทพมหานคร             เมือง          NaN
# 2                 นครปฐม             เมือง          NaN
# 3          กรุงเทพมหานคร            หัวหิน          NaN
# 4          กรุงเทพมหานคร            หัวหิน          NaN
# ...                  ...               ...          ...
# 433548               NaN               NaN          NaN
# 433549               NaN               NaN          NaN
# 433550               NaN               NaN          NaN
# 433551               NaN               NaN          NaN
# 433552               NaN               NaN          NaN
#
# [3056776 rows x 12 columns]

# %% [markdown]
# ## เลือกเฉพาะคอลัมน์ที่สนใจ

# %%
covid_data = covid[['announce_date','sex','age','nationality','risk','province_of_onset']]
covid_data
# Out:
#        announce_date   sex   age nationality  \
# 0          12/1/2020  หญิง  61.0       China
# 1          17/1/2020  หญิง  74.0       China
# 2          22/1/2020  หญิง  73.0    Thailand
# 3          22/1/2020   ชาย  68.0       China
# 4          24/1/2020  หญิง  66.0       China
# ...              ...   ...   ...         ...
# 433548     18/3/2022  หญิง   NaN         NaN
# 433549     18/3/2022  หญิง   NaN         NaN
# 433550     18/3/2022  หญิง   NaN         NaN
# 433551     18/3/2022  หญิง   NaN         NaN
# 433552     18/3/2022  หญิง   NaN         NaN
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                  ...               ...
# 433548                  ทัณฑสถาน/เรือนจำ               NaN
# 433549                  ทัณฑสถาน/เรือนจำ               NaN
# 433550                  ทัณฑสถาน/เรือนจำ               NaN
# 433551                  ทัณฑสถาน/เรือนจำ               NaN
# 433552                  ทัณฑสถาน/เรือนจำ               NaN
#
# [3056776 rows x 6 columns]

# %% [markdown]
# ## ตรวจสอบค่า Missing

# %%
covid_data.isnull().any() #ดูว่าแต่ละ column มีค่า missing มั้ย
# Out:
# announce_date        False
# sex                   True
# age                   True
# nationality           True
# risk                  True
# province_of_onset     True
# dtype: bool

# %%
covid_data[['sex']] = covid_data[['sex']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
covid_data[['nationality']] = covid_data[['nationality']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
covid_data[['province_of_onset']] = covid_data[['province_of_onset']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
covid_data[['risk']] = covid_data[['risk']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
covid_data.isnull().any() #เช็คข้อมูลในแต่ละคอลัมน์อีกครั้ง
# Out:
# announce_date        False
# sex                  False
# age                   True
# nationality          False
# risk                 False
# province_of_onset    False
# dtype: bool

# %%
set(covid_data['province_of_onset'])
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำเพงเพชร',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขอนแก่่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จ.สุราษฎร์ธานี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชลบุุรี',
#  'ชอนแก่น',
#  'ชัยนาถ',
#  'ชัยนาท',
#  'ชัยบาดาล',
#  'ชัยภูมิ',
#  'ชัยภูมิ\xa0',
#  'ชุมพร',
#  'ชุุมพร',
#  'ชุุุมพร',
#  'ดอนมดแดง',
#  'ดินแดง',
#  'ตรัง',
#  'ตรััง',
#  'ตราด',
#  'ตราด\xa0',
#  'ตาก',
#  'ต่างจังหวัด',
#  'ทุ่งเสลี่ยม',
#  'ท้ายบ้าน',
#  'ธารโต',
#  'นคนปฐม',
#  'นคปฐม',
#  'นครนปฐม',
#  'นครนาชสีมา',
#  'นครนายก',
#  'นครปฐม',
#  'นครปฐม\xa0',
#  'นครปบม',
#  'นครพนม',
#  'นครพนม\xa0',
#  'นครยายก',
#  'นครราขสีมา',
#  'นครราชธานี',
#  'นครราชศรีมา',
#  'นครราชสสีมา',
#  'นครราชสีมา',
#  'นครราชสีมา ลพบุรี',
#  'นครราชสีมา\xa0',
#  'นครศรธรรมราช',
#  'นครศรี',
#  'นครศรีธรมมราช',
#  'นครศรีธรมราช',
#  'นครศรีธรรมราข',
#  'นครศรีธรรมราช',
#  'นครศรีฯ',
#  'นครศรีีธรรมราช',
#  'นครศร๊ธรรมราช',
#  'นครศร๊ะรรมราช',
#  'นครสรรค์',
#  'นครสรีธรรมราช',
#  'นครสวรรค',
#  'นครสวรรค์',
#  'นครสวรรค์\xa0',
#  'นครสีธรรมราช',
#  'นครฯ',
#  'นคราชสีมา',
#  'นครีศรีธรรมราช',
#  'นตรนายก',
#  'นตรปฐม',
#  'นนทบุรี',
#  'นนทบุรี\xa0',
#  'นนทบุุรี',
#  'นนทุบรี',
#  'นนทุรี',
#  'นนมบุรี',
#  'นรศรีธรรมราช',
#  'นราธิวาส',
#  'นราธิวาส\u200b',
#  'นราธฺวาส',
#  'นอกเขต',
#  'นาราธิวาส',
#  'นาวัง',
#  'น่าน',
#  'น่าน/ฉะเชิงเทรา',
#  'บางกรวย',
#  'บางกะปิ',
#  'บางนา',
#  'บางปะอิน',
#  'บางละมุง',
#  'บางศรีเมือง',
#  'บางเพียง',
#  'บึงกาฬ',
#  'บึงโขงหลง',
#  'บุรีรัมภ์',
#  'บุรีรัมย์',
#  'บุรีรัมย์\xa0',
#  'บุรีรัยม์',
#  'บุรีรีมย์',
#  'บ้านหลวง',
#  'ปจ',
#  'ปทึมธานี',
#  'ปทุทธานี',
#  'ปทุมฑานี',
#  'ปทุมทานี',
#  'ปทุมธาน',
#  'ปทุมธานี',
#  'ปทุมธานี.',
#  'ปทุมธานี\xa0',
#  'ปทุมธานีี',
#  'ปทุมาธานี',
#  'ปทุุมธานี',
#  'ปธุมธานี',
#  'ปมุมธานี',
#  'ประจวนคีรีขันธ็',
#  'ประจวบ',
#  'ประจวบคิรีขันธ์',
#  'ประจวบคีรขันธ์',
#  'ประจวบคีรขัันธ์',
#  'ประจวบคีรีขัน',
#  'ประจวบคีรีขันธื',
#  'ประจวบคีรีขันธฺ',
#  'ประจวบคีรีขันธ์',
#  'ประจวบคีรีขันธ์\xa0',
#  'ประจวบคีรีขันธ์์',
#  'ประจวบคีรีขัันธ์',
#  'ประจวบคีีรีขันธ์',
#  'ประจวบฯ',
#  'ประทุมธานี',
#  'ประเทศกัมพูชา',
#  'ปราจีนบุรี',
#  'ปราจีบุรี',
#  'ปลวกแดง',
#  'ปลายพระยา',
#  'ปอยเปต',
#  'ปัตตนรี',
#  'ปัตตานนี',
#  'ปัตตานี',
#  'ปัตตานีี',
#  'ปัตาตานี',
#  'ปัว',
#  'ปััตตานี',
#  'ปุทมธานี',
#  'ป่าโมก',
#  'พม่า',
#  'พรหมพิราม',
#  'พระนครศรียุธยา',
#  'พระนครศรีอยุทธยา',
#  'พระนครศรีอยุทยา',
#  'พระนครศรีอยุธยา',
#  'พระนครศรีอยุธยา\xa0',
#  'พะเยา',
#  'พังงา',
#  'พัทยา',
#  'พัทลุง',
#  'พัทลุุง',
#  'พัังงา',
#  'พิจิตร',
#  'พิษณุโลก',
#  'พิษณุโลก\xa0',
#  'พิษณูโลก',
#  'ฟินแลนด์',
#  'ภาษีเจริญ',
#  'ภุเก็ต',
#  'ภูุเก็ต',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'ภูเก็็ต',
#  'ภูเพียง',
#  'มหาสาคาม',
#  'มหาสารคาม',
#  'มาเลเซีย',
#  'มุกดาหาร',
#  'มุกาดหาร',
#  'ยะลา',
#  'ยานนาวา',
#  'ยโสธร',
#  'ร.จ.จ.นราธิวาส',
#  'รอ',
#  'ระนอง',
#  'ระบุ',
#  'ระยอง',
#  'ระยอง\xa0',
#  'ระอยง',
#  'ราชบบุรี',
#  'ราชบุรี',
#  'ราชบุรีี',
#  'ราชบุรี\u200b',
#  'ราชุรี',
#  'ราชเทวี',
#  'ร้องกวาง',
#  'ร้อยเอ็ด',
#  'ลบุรี',
#  'ลพบุรี',
#  'ลพบุรี.',
#  'ลพบุรี\xa0',
#  'ลอง',
#  'ลาดกระบัง',
#  'ลาดพร้าว',
#  'ลาว',
#  'ลำปาง',
#  'ลำพูน',
#  'ลำพูน\u200b',
#  'ลำพููน',
#  'ลำลูกกา',
#  'วังชิ้น',
#  'วังทอง',
#  'วิเศษชัยชาญ',
#  'ศรีษะสะเกษ',
#  'ศรีษะเกษ',
#  'ศรีสระเกษ',
#  'ศรีสะเกษ',
#  'ศีรสะเกษ',
#  'สกลนคร',
#  'สครสวรรค์',
#  'สงขลา',
#  'สงขลา\u200b',
#  'สตูล',
#  'สถานที่ทำงาน',
#  'สพรรณบุรี',
#  'สมถทรปราการ',
#  'สมทรสงคราม',
#  'สมทรสาคร',
#  'สมุครปราการ',
#  'สมุครสาคร',
#  'สมุท',
#  'สมุทปราการ',
#  'สมุทรปรากร',
#  'สมุทรปรากรร',
#  'สมุทรปรากา',
#  'สมุทรปราการ',
#  'สมุทรปราการ\xa0',
#  'สมุทรศาคร',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สมุทรสาคร\xa0',
#  'สมุทรสาคา',
#  'สมุทรสาคาร',
#  'สมุทรสาทร',
#  'สมุทรสารคร',
#  'สมุทราปราการ',
#  'สมุทราสาคร',
#  'สมุทสงคราม',
#  'สมุทสาคร',
#  'สมุย',
#  'สมุุทรปราการ',
#  'สมุุทรสงคราม',
#  'สมุุทรสาคร',
#  'สระก้ว',
#  'สระบุรี',
#  'สระบุรี\xa0',
#  'สระแก้ว',
#  'สวิสเซอร์แลนด์',
#  'สอง',
#  'สองแคว',
#  'สะพานสูง',
#  'สะแก้ว',
#  'สัตหีบ',
#  'สัมผัสผู้ป่วยยืนยัน COVID20',
#  'สามุทรสาคร',
#  'สารคาม',
#  'สารภี',
#  'สิงห์บุรี',
#  'สิงห์บุรี\xa0',
#  'สุทรปราการ',
#  'สุพรรญบุรี',
#  'สุพรรณบุรั',
#  'สุพรรณบุรี',
#  'สุพรรณบุรี\xa0',
#  'สุมทรปราการ',
#  'สุมทรสาคร',
#  'สุมุทรปราการ',
#  'สุมุทรสาคร',
#  'สุระบุรี',
#  'สุราษ',
#  'สุราษฎณ์ธานี',
#  'สุราษฎธานี',
#  'สุราษฎร์',
#  'สุราษฎร์ธานี',
#  'สุราษฎร์ฯ',
#  'สุราษฎร์์ธานี',
#  'สุราษฎ์ธานี',
#  'สุราษฏร์ธานี',
#  'สุราษธานี',
#  'สุราษร์ฎธานี',
#  'สุราษร์ธานี',
#  'สุราษฯ',
#  'สุรินทรื',
#  'สุรินทร์',
#  'สุรินทร์ 32150',
#  'สุรินทร์,รีสะเกษ',
#  'สุรินทร์\xa0',
#  'สุริมทร์',
#  'สุริะแก้ว',
#  'สุวรรณภูมิ',
#  'สุุพรรณบุรี',
#  'สุุราษฎร์ธานี',
#  'สุุราษฏร์ธานี',
#  'สุุราษฯ',
#  'สุุรินทร์',
#  'สุุุโขทัย',
#  'สุโขทับ',
#  'สุโขทัย',
#  'สุโขทัย\xa0',
#  'สูงเม่น',
#  'หนวงบัวลำภู',
#  'หนองคาย',
#  'หนองงคาย',
#  'หนองบัวภู',
#  'หนองบัวลำพูน',
#  'หนองบัวลำภู',
#  'หนองบัวลําภู',
#  'หนองบััวลำภู',
#  'หนองม่วงไข่',
#  'หนอบัวลำภู',
#  'หลายจังหวัด',
#  'หัวหิน',
#  'ห้วยขวาง',
#  'อยุทธยา',
#  'อยุธยา',
#  'อยุุธยา',
#  'อำนาจเจริญ',
#  'อำนาญเจริญ',
#  'อำนาเจริญ',
#  'อิสราเอล',
#  'อุดธานี',
#  'อุดร',
#  'อุดรธาณี',
#  'อุดรธานี',
#  'อุดรธานี\xa0',
#  'อุดรธานีี',
#  'อุดรราชธานี',
#  'อุตรดิตถ์',
#  'อุตรดิตถ์\xa0',
#  'อุตรดิตถ์์',
#  'อุตรดิษถ์',
#  'อุตรดิิตถ์',
#  'อุตรติดถ์',
#  'อุทัยธานี',
#  'อุทัยานี',
#  'อุบลราขธานี',
#  'อุบลราชธานี',
#  'อุบลราชธานี\xa0',
#  'อุุครดิตถ์',
#  'อุุดรธาน',
#  'อุุดรธานี',
#  'อุุตรดิตถ์',
#  'อุุทัยธานี',
#  'อุุบลราชธานี',
#  'อ่งทอง',
#  'อ่างทอง',
#  'อ่างทอง\xa0',
#  'อํานาจเจริญ',
#  'เชิงเทรา',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เชียรใหญ่',
#  'เชีียงราย',
#  'เชีียงใหม่',
#  'เด่นชัย',
#  'เพขรบุรี',
#  'เพขรบูรณื',
#  'เพขรบูรณ์',
#  'เพชรบุรณ์',
#  'เพชรบุรี',
#  'เพชรบุรึ',
#  'เพชรบุุรี',
#  'เพชรบุูรณ์',
#  'เพชรบูรณ์',
#  'เพชรบูรณ์\xa0',
#  'เพชรบูร์',
#  'เพชรบููรณ์',
#  'เมือง',
#  'เมืองตาก',
#  'เมืองน่าน',
#  'เมืองปัตตานี',
#  'เรือ',
#  'เลย',
#  'เลย\xa0',
#  'เวียงจันทร์',
#  'เวียงสา',
#  'แพร่',
#  'แม่ทะ',
#  'แม่ฮ่องสอน',
#  'แล้วป่วย',
#  'โพธิ์ทอง',
#  'ไชโย',
#  'ไม่มีชื่อหอพัก',
#  'ไม่ระบุ'}

# %%
len(set(covid_data['province_of_onset']))
# Out:
# 434

# %%
#ทำข้อมูลให้เหมือนกัน
covid_data['province_of_onset'].replace({'\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',
 'USA':'กรุงเทพมหานคร',
 '\xa0กาญจนบุรี':'กาญจนบุรี',
 '\xa0ชลบุรี':'ชลบุรี',
 '\xa0ตราด':'ตราด',
 '\xa0นครปฐม':'นครปฐม',
 '\xa0สมุทรสงคราม':'สมุทรสงคราม',
 '\xa0สมุทรสาคร':'สมุทรสาคร',
 '\xa0อุทัยธานี':'อุทัยธานี',
 'กทม':'กรุงเทพมหานคร',
 'กทม.':'กรุงเทพมหานคร',
 'กบินทร์บุรี':'ปราจีนบุรี',
 'กระบี่':'กระบี่',
 'กระบี่ี่':'กระบี่',
 'กรุงเทพ':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร.':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร',
 'กรุงเทพฯ':'กรุงเทพมหานคร',
 'กะทู้':'ไม่ระบุ',
 'กัมพูชา':'กรุงเทพมหานคร',
 'กาญจนบุรี':'กาญจนบุรี',
 'กาญจบุรี':'กาญจนบุรี',
 'กาญนบุรี':'กาญจนบุรี',
 'กาฬสิน':'กาฬสินธุ์',
 'กาฬสินธิ์':'กาฬสินธุ์',
 'กาฬสินธุ์':'กาฬสินธุ์',
 'กาฬสินธุ์\xa0':'กาฬสินธุ์',
 'กาฬสินธ์':'กาฬสินธุ์',
 'กำเพงเพชร':'กำแพงเพชร',
 'กำแพง':'กำแพงเพชร',
 'กำแพงเพชร':'กำแพงเพชร',
 'กำแพงเพชร\xa0':'กำแพงเพชร',
 'กําแพงเพชร':'กำแพงเพชร',
 'ขอนแก่น':'ขอนแก่น',
 'ขอนแก่น\xa0':'ขอนแก่น',
 'ขอนแก่่น':'ขอนแก่น',
 'ขัยนาท':'ชัยนาท',
 'ขัยภูมิ':'ชัยภูมิ',
 'ขานุวรลักษณ์บุรี':'กำแพงเพชร',
 'คนไทยเดินทางกลับจากต่างประเทศ':'กรุงเทพมหานคร',
 'คลองเตย':'กรุงเทพมหานคร',
 'จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
 'จ.ภูเก็ต':'ภูเก็ต',
 'จ.ราชบุรี':'ราชบุรี',
 'จ.สุราษฎร์ธานี':'สุราษฎร์ธานี',
 'จังหวัดสมุทรสาคร':'สมุทรสาคร',
 'จันทบุรี':'จันทบุรี',
 'ฉะเชองเทราร':'ฉะเชิงเทรา',
 'ฉะเชิงเทรา':'ฉะเชิงเทรา',
 'ชมพร':'ชุมพร',
 'ชลบุรี':'ชลบุรี',
 'ชลบุรี\t':'ชลบุรี',
 'ชลบุรี\xa0':'ชลบุรี',
 'ชลบุุรี':'ชลบุรี',
 'ชอนแก่น':'ขอนแก่น',
 'ชัยนาถ':'ชัยนาท',
 'ชัยนาท':'ชัยนาท',
 'ชัยบาดาล':'ลพบุรี',
 'ชัยภูมิ':'ชัยภูมิ',
 'ชัยภูมิ\xa0':'ชัยภูมิ',
 'ชุมพร':'ชุมพร',
 'ชุุมพร':'ชุมพร',
 'ชุุุมพร':'ชุมพร',
 'ดอนมดแดง':'อุบลราชธานี',
 'ดินแดง':'กรุงเทพมหานคร',
 'ตรัง':'ตรัง',
 'ตรััง':'ตรัง',
 'ตราด':'ตราด',
 'ตราด\xa0':'ตราด',
 'ตาก':'ตาก',
 'ตากใบ':'นราธิวาส',
 'ต่างจังหวัด':'กรุงเทพมหานคร',
 'ทุ่งเสลี่ยม':'สุโขทัย',
 'ท้ายบ้าน':'สมุทรปราการ',
 'ธารโต':'ยะลา',
 'นคนปฐม':'นครปฐม',
 'นคปฐม':'นครปฐม',
 'นครนปฐม':'นครปฐม',
 'นครนาชสีมา':'นครราชสีมา',
 'นครนายก':'นครนายก',
 'นครปฐม':'นครปฐม',
 'นครปฐม\xa0':'นครปฐม',
 'นครปบม':'นครปฐม',
 'นครพนม':'นครพนม',
 'นครพนม\xa0':'นครพนม',
 'นครยายก':'นครนายก',
 'นครราขสีมา':'นครราชสีมา',
 'นครราชธานี':'นครราชสีมา',
 'นครราชศรีมา':'นครราชสีมา',
 'นครราชสสีมา':'นครราชสีมา',
 'นครราชสีมา':'นครราชสีมา',
 'นครราชสีมา ลพบุรี':'นครราชสีมา',
 'นครราชสีมา\xa0':'นครราชสีมา',
 'นครศรธรรมราช':'นครศรีธรรมราช',
 'นครศรี':'นครศรีธรรมราช',
 'นครศรีธรมมราช':'นครศรีธรรมราช',
 'นครศรีธรมราช':'นครศรีธรรมราช',
 'นครศรีธรรมราข':'นครศรีธรรมราช',
 'นครศรีธรรมราช':'นครศรีธรรมราช',
 'นครศรีฯ':'นครศรีธรรมราช',
 'นครศรีีธรรมราช':'นครศรีธรรมราช',
 'นครศร๊ธรรมราช':'นครศรีธรรมราช',
 'นครศร๊ะรรมราช':'นครศรีธรรมราช',
 'นครสรรค์':'นครสวรรค์',
 'นครสรีธรรมราช':'นครศรีธรรมราช',
 'นครสวรรค':'นครสวรรค์',
 'นครสวรรค์':'นครสวรรค์',
 'นครสวรรค์\xa0':'นครสวรรค์',
 'นครสีธรรมราช':'นครศรีธรรมราช',
 'นครฯ':'นครราชสีมา',
 'นคราชสีมา':'นครราชสีมา',
 'นครีศรีธรรมราช':'นครศรีธรรมราช',
 'นตรนายก':'นครนายก',
 'นตรปฐม':'นครปฐม',
 'นนทบุรี':'นนทบุรี',
 'นนทบุรี\xa0':'นนทบุรี',
 'นนทบุุรี':'นนทบุรี',
 'นนทุบรี':'นนทบุรี',
 'นนทุรี':'นนทบุรี',
 'นนมบุรี':'นนทบุรี',
 'นรศรีธรรมราช':'นครศรีธรรมราช',
 'นราธิวาส':'นราธิวาส',
 'นราธิวาส\u200b':'นราธิวาส',
 'นราธฺวาส':'นราธิวาส',
 'นอกเขต':'ไม่ระบุ',
 'นาราธิวาส':'นราธิวาส',
 'นาวัง':'หนองบัวลำภู',
 'น่าน':'น่าน',
 'น่าน/ฉะเชิงเทรา':'น่าน',
 'บางกรวย':'นนทบุรี',
 'บางกะปิ':'กรุงเทพมหานคร',
 'บางนา':'กรุงเทพมหานคร',
 'บางปะอิน':'กรุงเทพมหานคร',
 'บางละมุง':'ชลบุรี',
 'บางศรีเมือง':'นนทบุรี',
 'บางเพียง':'สมุทรปราการ',
 'บึงกาฬ':'บึงกาฬ',
 'บึงโขงหลง':'บึงกาฬ',
 'บุรีรัมภ์':'บุรีรัมย์',
 'บุรีรัมย์':'บุรีรัมย์',
 'บุรีรัมย์\xa0':'บุรีรัมย์',
 'บุรีรัยม์':'บุรีรัมย์',
 'บุรีรีมย์':'บุรีรัมย์',
 'บ้านหลวง':'น่าน',
 'ปจ':'ไม่ระบุ',
 'ปทึมธานี':'ปทุมธานี',
 'ปทุทธานี':'ปทุมธานี',
 'ปทุมฑานี':'ปทุมธานี',
 'ปทุมทานี':'ปทุมธานี',
 'ปทุมธาน':'ปทุมธานี',
 'ปทุมธานี':'ปทุมธานี',
 'ปทุมธานี.':'ปทุมธานี',
 'ปทุมธานี\xa0':'ปทุมธานี',
 'ปทุมธานีี':'ปทุมธานี',
 'ปทุมาธานี':'ปทุมธานี',
 'ปทุุมธานี':'ปทุมธานี',
 'ปธุมธานี':'ปทุมธานี',
 'ปมุมธานี':'ปทุมธานี',
 'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์',
 'ประจวบ':'ประจวบคีรีขันธ์',
 'ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีรขันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
 'ประจวบฯ':'ประจวบคีรีขันธ์',
 'ประทุมธานี':'ปทุมธานี',
 'ประเทศกัมพูชา':'กรุงเทพมหานคร',
 'ปราจีนบุรี':'ปราจีนบุรี',
 'ปราจีบุรี':'ปราจีนบุรี',
 'ปลวกแดง':'ระยอง',
 'ปลายพระยา':'กระบี่',
 'ปอยเปต':'กรุงเทพมหานคร',
 'ปัตตนรี':'ปัตตานี',
 'ปัตตานนี':'ปัตตานี',
 'ปัตตานี':'ปัตตานี',
 'ปัตตานีี':'ปัตตานี',
 'ปัตาตานี':'ปัตตานี',
 'ปัว':'เพชรบุรี',
 'ปััตตานี':'ปัตตานี',
 'ปุทมธานี':'ปทุมธานี',
 'ป่าโมก':'สุโขทัย',
 'พม่า':'กรุงเทพมหานคร',
 'พรหมพิราม':'พิษณุโลก',
 'พระนครศรียุธยา':'พระนครศรีอยุธยา',
 'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา',
 'พระนครศรีอยุทยา':'พระนครศรีอยุธยา',
 'พระนครศรีอยุธยา':'พระนครศรีอยุธยา',
 'พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา',
 'พะเยา':'พะเยา',
 'พังงา':'พังงา',
 'พัทยา':'ชลบุรี',
 'พัทลุง':'พัทลุง',
 'พัทลุุง':'พัทลุง',
 'พัังงา':'พังงา',
 'พิจิตร':'พิจิตร',
 'พิษณุโลก':'พิษณุโลก',
 'พิษณุโลก\xa0':'พิษณุโลก',
 'พิษณูโลก':'พิษณุโลก',
 'ฟินแลนด์':'กรุงเทพมหานคร',
 'ภาษีเจริญ':'กรุงเทพมหานคร',
 'ภุเก็ต':'ภูเก็ต',
 'ภูุเก็ต':'ภูเก็ต',
 'ภููเก็ต':'ภูเก็ต',
 'ภูเก็ต':'ภูเก็ต',
 'ภูเก็็ต':'ภูเก็ต',
 'ภูเพียง':'น่าน',
 'มหาสาคาม':'มหาสารคาม',
 'มหาสารคาม':'มหาสารคาม',
 'มาเลเซีย':'กรุงเทพมหานคร',
 'มุกดาหาร':'มุกดาหาร',
 'มุกาดหาร':'มุกดาหาร',
 'ยะลา':'ยะลา',
 'ยานนาวา':'กรุงเทพมหานคร',
 'ยโสธร':'ยโสธร',
 'ร.จ.จ.นราธิวาส':'นราธิวาส',
 'รอ':'ไม่ระบุ',
 'ระนอง':'ระนอง',
 'ระบุ':'ไม่ระบุ',
 'ระยอง':'ระยอง',
 'ระยอง\xa0':'ระยอง',
 'ระอยง':'ระยอง',
 'ราชบบุรี':'ราชบุรี',
 'ราชบุรี':'ราชบุรี',
 'ราชบุรีี':'ราชบุรี',
 'ราชบุรี\u200b':'ราชบุรี',
 'ราชุรี':'ราชบุรี',
 'ราชเทวี':'กรุงเทพมหานคร',
 'ร้องกวาง':'แพร่',
 'ร้อยเอ็ด':'ร้อยเอ็ด',
 'ลบุรี':'ลพบุรี',
 'ลพบุรี':'ลพบุรี',
 'ลพบุรี.':'ลพบุรี',
 'ลพบุรี\xa0':'ลพบุรี',
 'ลอง':'ไม่ระบุ',
 'ลาดกระบัง':'กรุงเทพมหานคร',
 'ลาดพร้าว':'กรุงเทพมหานคร',
 'ลาว':'กรุงเทพมหานคร',
 'ลำปาง':'ลำปาง',
 'ลำพูน':'ลำพูน',
 'ลำพูน\u200b':'ลำพูน',
 'ลำพููน':'ลำพูน',
 'ลำลูกกา':'กรุงเทพมหานคร',
 'วังชิ้น':'แพร่',
 'วังทอง':'พิษณุโลก',
 'วิเศษชัยชาญ':'อ่างทอง',
 'ศรีษะสะเกษ':'ศรีสะเกษ',
 'ศรีษะเกษ':'ศรีสะเกษ',
 'ศรีสระเกษ':'ศรีสะเกษ',
 'ศรีสะเกษ':'ศรีสะเกษ',
 'ศีรสะเกษ':'ศรีสะเกษ',
 'สกลนคร':'สกลนคร',
 'สครสวรรค์':'นครสวรรค์',
 'สงขลา':'สงขลา',
 'สงขลา\u200b':'สงขลา',
 'สตูล':'สตูล',
 'สถานที่ทำงาน':'ไม่ระบุ',
 'สพรรณบุรี':'สุพรรณบุรี',
 'สมถทรปราการ':'สมุทรปราการ',
 'สมทรสงคราม':'สมุทรสงคราม',
 'สมทรสาคร':'สมุทรสาคร',
 'สมุครปราการ':'สมุทรปราการ',
 'สมุครสาคร':'สมุทรสาคร',
 'สมุท':'สมุทรปราการ',
 'สมุทปราการ':'สมุทรปราการ',
 'สมุทรปรากร':'สมุทรปราการ',
 'สมุทรปรากรร':'สมุทรปราการ',
 'สมุทรปรากา':'สมุทรปราการ',
 'สมุทรปราการ':'สมุทรปราการ',
 'สมุทรปราการ\xa0':'สมุทรปราการ',
 'สมุทรศาคร':'สมุทรสาคร',
 'สมุทรสงคราม':'สมุทรสาคร',
 'สมุทรสาคร':'สมุทรสาคร',
 'สมุทรสาคร\xa0':'สมุทรสาคร',
 'สมุทรสาคา':'สมุทรสาคร',
 'สมุทรสาคาร':'สมุทรสาคร',
 'สมุทรสาทร':'สมุทรสาคร',
 'สมุทรสารคร':'สมุทรสาคร',
 'สมุทราปราการ':'สมุทรปราการ',
 'สมุทราสาคร':'สมุทรสาคร',
 'สมุทสงคราม':'สมุทรสงคราม',
 'สมุทสาคร':'สมุทรสาคร',
 'สมุย':'สุราษฎร์ธานี',
 'สมุุทรปราการ':'สมุทรปราการ',
 'สมุุทรสงคราม':'สมุทรสงคราม',
 'สมุุทรสาคร':'สมุทรสาคร',
 'สระก้ว':'สระแก้ว',
 'สระบุรี':'สระบุรี',
 'สระบุรี\xa0':'สระบุรี',
 'สระแก้ว':'สระแก้ว',
 'สรินทร์':'สุรินทร์',
 'สวิสเซอร์แลนด์':'กรุงเทพมหานคร',
 'สอง':'ไม่ระบุ',
 'สองแคว':'เชียงใหม่',
 'สะพานสูง':'กรุงเทพมหานคร',
 'สะแก้ว':'สระแก้ว',
 'สัตหีบ':'ชลบุรี',
 'สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่ระบุ',
 'สามุทรสาคร':'สมุทรสาคร',
 'สารคาม':'มหาสารคาม',
 'สารภี':'เชียงใหม่',
 'สิงห์บุรี':'สิงห์บุรี',
 'สิงห์บุรี\xa0':'สิงห์บุรี',
 'สุทรปราการ':'สมุทรปราการ',
 'สุพรรญบุรี':'สุพรรณบุรี',
 'สุพรรณบุรั':'สุพรรณบุรี',
 'สุพรรณบุรี':'สุพรรณบุรี',
 'สุพรรณบุรี\xa0':'สุพรรณบุรี',
 'สุมทรปราการ':'สมุทรปราการ',
 'สุมทรสาคร':'สมุทรสาคร',
 'สุมุทรปราการ':'สมุทรปราการ',
 'สุมุทรสาคร':'สมุทรสาคร',
 'สุระบุรี':'สระบุรี',
 'สุราษ':'สุราษฎร์ธานี',
 'สุราษฎณ์ธานี':'สุราษฎร์ธานี',
 'สุราษฎธานี':'สุราษฎร์ธานี',
 'สุราษฎร์':'สุราษฎร์ธานี',
 'สุราษฎร์ธานี':'สุราษฎร์ธานี',
 'สุราษฎร์ฯ':'สุราษฎร์ธานี',
 'สุราษฎร์์ธานี':'สุราษฎร์ธานี',
 'สุราษฎ์ธานี':'สุราษฎร์ธานี',
 'สุราษฏร์ธานี':'สุราษฎร์ธานี',
 'สุราษธานี':'สุราษฎร์ธานี',
 'สุราษร์ฎธานี':'สุราษฎร์ธานี',
 'สุราษร์ธานี':'สุราษฎร์ธานี',
 'สุราษฯ':'สุราษฎร์ธานี',
 'สุรินทรื':'สุรินทร์',
 'สุรินทร์':'สุรินทร์',
 'สุรินทร์ 32150':'สุรินทร์',
 'สุรินทร์,รีสะเกษ':'สุรินทร์',
 'สุรินทร์\xa0':'สุรินทร์',
 'สุริมทร์':'สุรินทร์',
 'สุริะแก้ว':'สระแก้ว',
 'สุวรรณภูมิ':'กรุงเทพมหานคร',
 'สุุพรรณบุรี':'สุพรรณบุรี',
 'สุุราษฎร์ธานี':'สุราษฎร์ธานี',
 'สุุราษฏร์ธานี':'สุราษฎร์ธานี',
 'สุุราษฯ':'สุราษฎร์ธานี',
 'สุุรินทร์':'สุรินทร์',
 'สุุุโขทัย':'สุโขทัย',
 'สุโขทับ':'สุโขทัย',
 'สุโขทัย':'สุโขทัย',
 'สุโขทัย\xa0':'สุโขทัย',
 'สูงเม่น':'แพร่',
 'หนวงบัวลำภู':'หนองบัวลำภู',
 'หนองคาย':'หนองคาย',
 'หนองงคาย':'หนองคาย',
 'หนองบัวภู':'หนองบัวลำภู',
 'หนองบัวลำพูน':'หนองบัวลำภู',
 'หนองบัวลำภู':'หนองบัวลำภู',
 'หนองบัวลําภู':'หนองบัวลำภู',
 'หนองบััวลำภู':'หนองบัวลำภู',
 'หนองม่วงไข่':'แพร่',
 'หนอบัวลำภู':'หนองบัวลำภู',
 'หลายจังหวัด':'ไม่ระบุ',
 'หัวหิน':'ชลบุรี',
 'ห้วยขวาง':'กรุงเทพมหานคร',
 'อยุทธยา':'พระนครศรีอยุธยา',
 'อยุธยา':'พระนครศรีอยุธยา',
 'อยุุธยา':'พระนครศรีอยุธยา',
 'อำนาจเจริญ':'อำนาจเจริญ',
 'อำนาจเจิญ':'อำนาจเจริญ',
 'อำนาญเจริญ':'อำนาจเจริญ',
 'อำนาเจริญ':'อำนาจเจริญ',
 'อิสราเอล':'กรุงเทพมหานคร',
 'อุดธานี':'อุดรธานี',
 'อุดร':'อุดรธานี',
 'อุดรธาณี':'อุดรธานี',
 'อุดรธานี':'อุดรธานี',
 'อุดรธานี\xa0':'อุดรธานี',
 'อุดรธานีี':'อุดรธานี',
 'อุดรราชธานี':'อุดรธานี',
 'อุตรดิตถ์':'อุตรดิตถ์',
 'อุตรดิตถ์\xa0':'อุตรดิตถ์',
 'อุตรดิตถ์์':'อุตรดิตถ์',
 'อุตรดิษถ์':'อุตรดิตถ์',
 'อุตรดิิตถ์':'อุตรดิตถ์',
 'อุตรติดถ์':'อุตรดิตถ์',
 'อุทัยธานี':'อุทัยธานี',
 'อุทัยานี':'อุทัยธานี',
 'อุบลราขธานี':'อุบลราชธานี',
 'อุบลราชธานี':'อุบลราชธานี',
 'อุบลราชธานี\xa0':'อุบลราชธานี',
 'อุุครดิตถ์':'อุตรดิตถ์',
 'อุุดรธาน':'อุดรธานี',
 'อุุดรธานี':'อุดรธานี',
 'อุุตรดิตถ์':'อุตรดิตถ์',
 'อุุทัยธานี':'อุทัยธานี',
 'อุุบลราชธานี':'อุบลราชธานี',
 'อ่งทอง':'อ่างทอง',
 'อ่างทอง':'อ่างทอง',
 'อ่างทอง\xa0':'อ่างทอง',
 'อํานาจเจริญ':'อำนาจเจริญ',
 'เชิงเทรา':'ฉะเชิงเทรา',
 'เชียงราย':'เชียงราย',
 'เชียงใหม่':'เชียงใหม่',
 'เชียรใหญ่':'เชียงใหม่',
 'เชีียงราย':'เชียงราย',
 'เชีียงใหม่':'เชียงใหม่',
 'เด่นชัย':'แพร่',
 'เพขรบุรี':'เพชรบุรี',
 'เพขรบูรณื':'เพชรบูรณ์',
 'เพขรบูรณ์':'เพชรบูรณ์',
 'เพชรบุรณ์':'เพชรบูรณ์',
 'เพชรบุรี':'เพชรบุรี',
 'เพชรบุรึ':'เพชรบุรี',
 'เพชรบุุรี':'เพชรบุรี',
 'เพชรบุูรณ์':'เพชรบูรณ์',
 'เพชรบูรณ์':'เพชรบูรณ์',
 'เพชรบูรณ์\xa0':'เพชรบูรณ์',
 'เพชรบูร์':'เพชรบูรณ์',
 'เพชรบููรณ์':'เพชรบูรณ์',
 'เมือง':'ไม่ระบุ',
 'เมืองตาก':'ตาก',
 'เมืองน่าน':'น่าน',
 'เมืองปัตตานี':'ปัตตานี',
 'เรือ':'ไม่ระบุ',
 'เลย':'เลย',
 'เลย\xa0':'เลย',
 'เวียงจันทร์':'กรุงเทพมหานคร',
 'เวียงสา':'กรุงเทพมหานคร',
 'แพร่':'แพร่',
 'แม่ทะ':'ลำปาง',
 'แม่ฮ่องสอน':'แม่ฮ่องสอน',
 'แล้วป่วย':'ไม่ระบุ',
 'โพธิ์ทอง':'อ่างทอง',
 'ไชโย':'อ่างทอง',
 'ไม่มีชื่อหอพัก':'ไม่ระบุ',
 'ไม่ระบุ':'ไม่ระบุ'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
len(set(covid_data['province_of_onset'])) #มีค่าที่ชื่อว่า ไม่ระบุ
# Out:
# 78

# %%
data_gb = covid_data.groupby('province_of_onset').size().reset_index(name='จำนวนผู้ติดเชื้อ')  ### สร้างตารางที่รวมจำนวนผู้ป่วยในแต่ละจังหวัด
data_gb
# Out:
#    province_of_onset  จำนวนผู้ติดเชื้อ
# 0             กระบี่             16371
# 1      กรุงเทพมหานคร            571854
# 2          กาญจนบุรี             24469
# 3          กาฬสินธุ์             16477
# 4          กำแพงเพชร             12908
# ..               ...               ...
# 73         เพชรบูรณ์             17083
# 74               เลย             10878
# 75              แพร่              5877
# 76        แม่ฮ่องสอน              7378
# 77           ไม่ระบุ            156639
#
# [78 rows x 2 columns]

# %%
covid_dropped = covid_data.dropna() #drop ค่าอายุที่ว่างออกจากตาราง

# %%
covid_dropped
# Out:
#        announce_date      sex   age nationality  \
# 0          12/1/2020     หญิง  61.0       China
# 1          17/1/2020     หญิง  74.0       China
# 2          22/1/2020     หญิง  73.0    Thailand
# 3          22/1/2020      ชาย  68.0       China
# 4          24/1/2020     หญิง  66.0       China
# ...              ...      ...   ...         ...
# 433445     18/3/2022  ไม่ระบุ  43.0     ไม่ระบุ
# 433446     18/3/2022  ไม่ระบุ  21.0     ไม่ระบุ
# 433447     18/3/2022  ไม่ระบุ  22.0     ไม่ระบุ
# 433448     18/3/2022  ไม่ระบุ  25.0     ไม่ระบุ
# 433449     18/3/2022  ไม่ระบุ  64.0     ไม่ระบุ
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                  ...               ...
# 433445                             อื่นๆ           ไม่ระบุ
# 433446                             อื่นๆ     กรุงเทพมหานคร
# 433447                             อื่นๆ     กรุงเทพมหานคร
# 433448                             อื่นๆ     กรุงเทพมหานคร
# 433449                             อื่นๆ         กำแพงเพชร
#
# [2944755 rows x 6 columns]

# %%
covid_finish = covid_dropped.merge(data_gb,how='left',left_on='province_of_onset',right_on = 'province_of_onset') 
covid_finish
# Out:
#         announce_date      sex   age nationality  \
# 0           12/1/2020     หญิง  61.0       China
# 1           17/1/2020     หญิง  74.0       China
# 2           22/1/2020     หญิง  73.0    Thailand
# 3           22/1/2020      ชาย  68.0       China
# 4           24/1/2020     หญิง  66.0       China
# ...               ...      ...   ...         ...
# 2944750     18/3/2022  ไม่ระบุ  43.0     ไม่ระบุ
# 2944751     18/3/2022  ไม่ระบุ  21.0     ไม่ระบุ
# 2944752     18/3/2022  ไม่ระบุ  22.0     ไม่ระบุ
# 2944753     18/3/2022  ไม่ระบุ  25.0     ไม่ระบุ
# 2944754     18/3/2022  ไม่ระบุ  64.0     ไม่ระบุ
#
#                                      risk province_of_onset  จำนวนผู้ติดเชื้อ
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม             71629
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# ...                                   ...               ...               ...
# 2944750                             อื่นๆ           ไม่ระบุ            156639
# 2944751                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944752                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944753                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944754                             อื่นๆ         กำแพงเพชร             12908
#
# [2944755 rows x 7 columns]

# %% [markdown]
# # สร้างตารางภูมิภาค

# %%
data_region = {'Province':['อำนาจเจริญ','บึงกาฬ','บุรีรัมย์','ชัยภูมิ','กาฬสินธุ์','ขอนแก่น','เลย','มหาสารคาม','มุกดาหาร','นครพนม','นครราชสีมา','หนองบัวลำภู','หนองคาย','ร้อยเอ็ด','สกลนคร','ศรีสะเกษ','สุรินทร์','อุบลราชธานี','อุดรธานี','ยโสธร','เชียงใหม่','เชียงราย','ลำปาง','ลำพูน','แม่ฮ่องสอน','น่าน','พะเยา','แพร่','อุตรดิตถ์','ตาก','สุโขทัย','พิษณุโลก','พิจิตร','กำแพงเพชร','เพชรบูรณ์','นครสวรรค์','อุทัยธานี','อ่างทอง','ชัยนาท','พระนครศรีอยุธยา','กรุงเทพมหานคร','ลพบุรี','นครปฐม','นนทบุรี','ปทุมธานี','สมุทรปราการ','สมุทรสาคร','สมุทรสงคราม','สระบุรี','สิงห์บุรี','สุพรรณบุรี','นครนายก','ฉะเชิงเทรา','จันทบุรี','ชลบุรี','ปราจีนบุรี','ระยอง','สระแก้ว','ตราด','กาญจนบุรี','ราชบุรี','เพชรบุรี','ประจวบคีรีขันธ์','ชุมพร','นครศรีธรรมราช','นราธิวาส','ปัตตานี','พัทลุง','สงขลา','สุราษฎร์ธานี','ยะลา','กระบี่','พังงา','ภูเก็ต','ระนอง','สตูล','ตรัง'],
             '6 ภูมิภาค (ภูมิศาสตร์)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],
}

# %%
data_region = pd.DataFrame.from_dict(data_region)
data_region
# Out:
#       Province 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ## merge ตาราง covid กับตาราง ภูมิภาค
# covid_dropped กับ data_region

# %%
data_cr = covid_finish.merge(data_region,how='left',left_on='province_of_onset',right_on = 'Province') 
data_cr
# Out:
#         announce_date      sex   age nationality  \
# 0           12/1/2020     หญิง  61.0       China
# 1           17/1/2020     หญิง  74.0       China
# 2           22/1/2020     หญิง  73.0    Thailand
# 3           22/1/2020      ชาย  68.0       China
# 4           24/1/2020     หญิง  66.0       China
# ...               ...      ...   ...         ...
# 2944750     18/3/2022  ไม่ระบุ  43.0     ไม่ระบุ
# 2944751     18/3/2022  ไม่ระบุ  21.0     ไม่ระบุ
# 2944752     18/3/2022  ไม่ระบุ  22.0     ไม่ระบุ
# 2944753     18/3/2022  ไม่ระบุ  25.0     ไม่ระบุ
# 2944754     18/3/2022  ไม่ระบุ  64.0     ไม่ระบุ
#
#                                      risk province_of_onset  จำนวนผู้ติดเชื้อ  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม             71629
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# ...                                   ...               ...               ...
# 2944750                             อื่นๆ           ไม่ระบุ            156639
# 2944751                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944752                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944753                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944754                             อื่นๆ         กำแพงเพชร             12908
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)
# 0        กรุงเทพมหานคร                   กลาง
# 1        กรุงเทพมหานคร                   กลาง
# 2               นครปฐม                   กลาง
# 3        กรุงเทพมหานคร                   กลาง
# 4        กรุงเทพมหานคร                   กลาง
# ...                ...                    ...
# 2944750            NaN                    NaN
# 2944751  กรุงเทพมหานคร                   กลาง
# 2944752  กรุงเทพมหานคร                   กลาง
# 2944753  กรุงเทพมหานคร                   กลาง
# 2944754      กำแพงเพชร                   กลาง
#
# [2944755 rows x 9 columns]

# %%
data_cr[['Province']] = data_cr[['Province']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_cr[['6 ภูมิภาค (ภูมิศาสตร์)']] = data_cr[['6 ภูมิภาค (ภูมิศาสตร์)']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data_cr
# Out:
#         announce_date      sex   age nationality  \
# 0           12/1/2020     หญิง  61.0       China
# 1           17/1/2020     หญิง  74.0       China
# 2           22/1/2020     หญิง  73.0    Thailand
# 3           22/1/2020      ชาย  68.0       China
# 4           24/1/2020     หญิง  66.0       China
# ...               ...      ...   ...         ...
# 2944750     18/3/2022  ไม่ระบุ  43.0     ไม่ระบุ
# 2944751     18/3/2022  ไม่ระบุ  21.0     ไม่ระบุ
# 2944752     18/3/2022  ไม่ระบุ  22.0     ไม่ระบุ
# 2944753     18/3/2022  ไม่ระบุ  25.0     ไม่ระบุ
# 2944754     18/3/2022  ไม่ระบุ  64.0     ไม่ระบุ
#
#                                      risk province_of_onset  จำนวนผู้ติดเชื้อ  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม             71629
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# ...                                   ...               ...               ...
# 2944750                             อื่นๆ           ไม่ระบุ            156639
# 2944751                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944752                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944753                             อื่นๆ     กรุงเทพมหานคร            571854
# 2944754                             อื่นๆ         กำแพงเพชร             12908
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)
# 0        กรุงเทพมหานคร                   กลาง
# 1        กรุงเทพมหานคร                   กลาง
# 2               นครปฐม                   กลาง
# 3        กรุงเทพมหานคร                   กลาง
# 4        กรุงเทพมหานคร                   กลาง
# ...                ...                    ...
# 2944750        ไม่ระบุ                ไม่ระบุ
# 2944751  กรุงเทพมหานคร                   กลาง
# 2944752  กรุงเทพมหานคร                   กลาง
# 2944753  กรุงเทพมหานคร                   กลาง
# 2944754      กำแพงเพชร                   กลาง
#
# [2944755 rows x 9 columns]

# %% [markdown]
# ## นำเข้าข้อมูลที่เลือกเอง

# %% [markdown]
# ข้อมูลพิกัดจังหวัด

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.1.post1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.2.1)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2018.9)

# %%
import geopandas # For working with geographical data
import pandas as pd

# %%
data_geometry =geopandas.read_file('/content/drive/MyDrive/Project_dataviz22/thai.json')
data_geometry
# Out:
#                    name                                           geometry
# 0          Mae Hong Son  POLYGON ((98.47780 19.70563, 98.48260 19.66410...
# 1              Chumphon  POLYGON ((99.50343 10.99705, 99.51157 10.86636...
# 2   Nakhon Si Thammarat  POLYGON ((100.12963 7.80172, 100.04457 7.82446...
# 3                Phuket  POLYGON ((98.41863 7.90375, 98.43165 7.91743, ...
# 4             Phang-nga  MULTIPOLYGON (((98.53631 8.11514, 98.60239 8.0...
# ..                  ...                                                ...
# 72        Nakhon Phanom  POLYGON ((104.75791 16.81889, 104.73452 16.804...
# 73             Mukdahan  POLYGON ((104.75791 16.81889, 104.77901 16.704...
# 74           Narathiwat  POLYGON ((101.72350 6.57438, 101.80836 6.46454...
# 75              Pattani  POLYGON ((101.72350 6.57438, 101.67837 6.57712...
# 76            Bueng Kan  POLYGON ((104.20333 18.01864, 104.12468 17.999...
#
# [77 rows x 2 columns]

# %%
set(data_geometry['name'])
# Out:
# {'Amnat Charoen',
#  'Ang Thong',
#  'Bangkok',
#  'Bueng Kan',
#  'Buri Ram',
#  'Chachoengsao',
#  'Chai Nat',
#  'Chaiyaphum',
#  'Chanthaburi',
#  'Chiang Mai',
#  'Chiang Rai',
#  'Chon Buri',
#  'Chumphon',
#  'Kalasin',
#  'Kamphaeng Phet',
#  'Kanchanaburi',
#  'Khon Kaen',
#  'Krabi',
#  'Lampang',
#  'Lamphun',
#  'Loei',
#  'Lop Buri',
#  'Mae Hong Son',
#  'Maha Sarakham',
#  'Mukdahan',
#  'Nakhon Nayok',
#  'Nakhon Pathom',
#  'Nakhon Phanom',
#  'Nakhon Ratchasima',
#  'Nakhon Sawan',
#  'Nakhon Si Thammarat',
#  'Nan',
#  'Narathiwat',
#  'Nong Bua Lam Phu',
#  'Nong Khai',
#  'Nonthaburi',
#  'Pathum Thani',
#  'Pattani',
#  'Phang-nga',
#  'Phatthalung',
#  'Phayao',
#  'Phetchabun',
#  'Phetchaburi',
#  'Phichit',
#  'Phitsanulok',
#  'Phra Nakhon Si Ayutthaya',
#  'Phrae',
#  'Phuket',
#  'Prachin Buri',
#  'Prachuap Khiri Khan',
#  'Ranong',
#  'Ratchaburi',
#  'Rayong',
#  'Roi Et',
#  'Sa kaeo',
#  'Sakon Nakhon',
#  'Samut Prakarn',
#  'Samut Sakhon',
#  'Samut Songkhram',
#  'Saraburi',
#  'Satun',
#  'Si Sa Ket',
#  'Sing Buri',
#  'Songkhla',
#  'Sukhothai',
#  'Suphan Buri',
#  'Surat Thani',
#  'Surin',
#  'Tak',
#  'Trang',
#  'Trat',
#  'Ubon Ratchathani',
#  'Udon Thani',
#  'Uthai Thani',
#  'Uttaradit',
#  'Yala',
#  'Yasothon'}

# %%
data_geometry['name'].replace({'Amnat Charoen':'อำนาจเจริญ',
 'Ang Thong':'อ่างทอง',
 'Bangkok':'กรุงเทพมหานคร',
 'Bueng Kan':'บึงกาฬ',
 'Buri Ram':'บุรีรัมย์',
 'Chachoengsao':'ฉะเชิงเทรา',
 'Chai Nat':'ชัยนาท',
 'Chaiyaphum':'ชัยภูมิ',
 'Chanthaburi':'จันทบุรี',
 'Chiang Mai':'เชียงใหม่',
 'Chiang Rai':' เชียงราย',
 'Chon Buri':'ชลบุรี',
 'Chumphon':'ชุมพร',
 'Kalasin':'กาฬสินธุ์',
 'Kamphaeng Phet':'กำแพงเพชร',
 'Kanchanaburi':'กาญจนบุรี',
 'Khon Kaen':'กระบี่',
 'Krabi':'กระบี่',
 'Lampang':'ลำปาง',
 'Lamphun':'ลำพูน',
 'Loei':'เลย',
 'Lop Buri':'ลพบุรี',
 'Mae Hong Son':'แม่ฮ่องสอน',
 'Maha Sarakham':'มหาสารคาม',
 'Mukdahan':'มุกดาหาร',
 'Nakhon Nayok':'นครนายก',
 'Nakhon Pathom':'นครปฐม',
 'Nakhon Phanom':'นครพนม',
 'Nakhon Ratchasima':'นครราชสีมา',
 'Nakhon Sawan':'นครสวรรค์',
 'Nakhon Si Thammarat':'นครศรีธรรมราช',
 'Nan':'น่าน',
 'Narathiwat':'นราธิวาส',
 'Nong Bua Lam Phu':'หนองบัวลำภู',
 'Nong Khai':'หนองคาย',
 'Nonthaburi':'นนทบุรี',
 'Pathum Thani':'ปทุมธานี',
 'Pattani':'ปัตตานี',
 'Phang-nga':'พังงา',
 'Phatthalung':'พัทลุง',
 'Phayao':'พะเยา',
 'Phetchabun':'เพชรบูรณ์',
 'Phetchaburi':'เพชรบุรี',
 'Phichit':'พิจิตร',
 'Phitsanulok':'พิษณุโลก',
 'Phra Nakhon Si Ayutthaya':'พระนครศรีอยุธยา',
 'Phrae':'แพร่',
 'Phuket':'ภูเก็ต',
 'Prachin Buri':'ปราจีนบุรี',
 'Prachuap Khiri Khan':'ประจวบคีรีขันธ์',
 'Ranong':'ระนอง',
 'Ratchaburi':'ราชบุรี',
 'Rayong':'ระยอง',
 'Roi Et':'ร้อยเอ็ด',
 'Sa kaeo':'สระแก้ว',
 'Sakon Nakhon':'สกลนคร',
 'Samut Prakarn':'สมุทรปราการ',
 'Samut Sakhon':'สมุทรสาคร',
 'Samut Songkhram':'สมุทรสงคราม',
 'Saraburi':'สระบุรี',
 'Satun':'สตูล',
 'Si Sa Ket':'ศรีสะเกษ',
 'Sing Buri':'สิงห์บุรี',
 'Songkhla':'สงขลา',
 'Sukhothai':'สุโขทัย',
 'Suphan Buri':'สุพรรณบุรี',
 'Surat Thani':'สุราษฎร์ธานี',
 'Surin':'สุรินทร์',
 'Tak':'ตาก',
 'Trang':'ตรัง',
 'Trat':'ตราด',
 'Ubon Ratchathani':'อุบลราชธานี',
 'Udon Thani':'อุดรธานี',
 'Uthai Thani':'อุทัยธานี',
 'Uttaradit':'อุตรดิตถ์',
 'Yala':'ยะลา',
 'Yasothon':'ยโสธร'
},inplace=True)

# %%
data_geometry
# Out:
#              name                                           geometry
# 0      แม่ฮ่องสอน  POLYGON ((98.47780 19.70563, 98.48260 19.66410...
# 1           ชุมพร  POLYGON ((99.50343 10.99705, 99.51157 10.86636...
# 2   นครศรีธรรมราช  POLYGON ((100.12963 7.80172, 100.04457 7.82446...
# 3          ภูเก็ต  POLYGON ((98.41863 7.90375, 98.43165 7.91743, ...
# 4           พังงา  MULTIPOLYGON (((98.53631 8.11514, 98.60239 8.0...
# ..            ...                                                ...
# 72         นครพนม  POLYGON ((104.75791 16.81889, 104.73452 16.804...
# 73       มุกดาหาร  POLYGON ((104.75791 16.81889, 104.77901 16.704...
# 74       นราธิวาส  POLYGON ((101.72350 6.57438, 101.80836 6.46454...
# 75        ปัตตานี  POLYGON ((101.72350 6.57438, 101.67837 6.57712...
# 76         บึงกาฬ  POLYGON ((104.20333 18.01864, 104.12468 17.999...
#
# [77 rows x 2 columns]

# %% [markdown]
# ## รวมตาราง data_cr (ข้อมูลโควิดกับภูมิภาค) กับ data_geometry

# %%
data_cr_new= data_cr[['announce_date','sex','age','risk','province_of_onset','จำนวนผู้ติดเชื้อ','6 ภูมิภาค (ภูมิศาสตร์)']]
data_cr_new
# Out:
#         announce_date      sex   age                              risk  \
# 0           12/1/2020     หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020     หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020     หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020      ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           24/1/2020     หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...      ...   ...                               ...
# 2944750     18/3/2022  ไม่ระบุ  43.0                             อื่นๆ
# 2944751     18/3/2022  ไม่ระบุ  21.0                             อื่นๆ
# 2944752     18/3/2022  ไม่ระบุ  22.0                             อื่นๆ
# 2944753     18/3/2022  ไม่ระบุ  25.0                             อื่นๆ
# 2944754     18/3/2022  ไม่ระบุ  64.0                             อื่นๆ
#
#         province_of_onset  จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)
# 0           กรุงเทพมหานคร            571854                   กลาง
# 1           กรุงเทพมหานคร            571854                   กลาง
# 2                  นครปฐม             71629                   กลาง
# 3           กรุงเทพมหานคร            571854                   กลาง
# 4           กรุงเทพมหานคร            571854                   กลาง
# ...                   ...               ...                    ...
# 2944750           ไม่ระบุ            156639                ไม่ระบุ
# 2944751     กรุงเทพมหานคร            571854                   กลาง
# 2944752     กรุงเทพมหานคร            571854                   กลาง
# 2944753     กรุงเทพมหานคร            571854                   กลาง
# 2944754         กำแพงเพชร             12908                   กลาง
#
# [2944755 rows x 7 columns]

# %%
data_final = data_cr_new.merge(data_geometry,how='left',left_on='province_of_onset',right_on = 'name') 
data_final
# Out:
#         announce_date      sex   age                              risk  \
# 0           12/1/2020     หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020     หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020     หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020      ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           24/1/2020     หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...      ...   ...                               ...
# 2960942     18/3/2022  ไม่ระบุ  43.0                             อื่นๆ
# 2960943     18/3/2022  ไม่ระบุ  21.0                             อื่นๆ
# 2960944     18/3/2022  ไม่ระบุ  22.0                             อื่นๆ
# 2960945     18/3/2022  ไม่ระบุ  25.0                             อื่นๆ
# 2960946     18/3/2022  ไม่ระบุ  64.0                             อื่นๆ
#
#         province_of_onset  จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0           กรุงเทพมหานคร            571854                   กลาง
# 1           กรุงเทพมหานคร            571854                   กลาง
# 2                  นครปฐม             71629                   กลาง
# 3           กรุงเทพมหานคร            571854                   กลาง
# 4           กรุงเทพมหานคร            571854                   กลาง
# ...                   ...               ...                    ...
# 2960942           ไม่ระบุ            156639                ไม่ระบุ
# 2960943     กรุงเทพมหานคร            571854                   กลาง
# 2960944     กรุงเทพมหานคร            571854                   กลาง
# 2960945     กรุงเทพมหานคร            571854                   กลาง
# 2960946         กำแพงเพชร             12908                   กลาง
#
#                   name                                           geometry
# 0        กรุงเทพมหานคร  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1        กรุงเทพมหานคร  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2               นครปฐม  POLYGON ((100.28321 14.11622, 100.26368 14.029...
# 3        กรุงเทพมหานคร  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 4        กรุงเทพมหานคร  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# ...                ...                                                ...
# 2960942            NaN                                               None
# 2960943  กรุงเทพมหานคร  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960944  กรุงเทพมหานคร  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960945  กรุงเทพมหานคร  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960946      กำแพงเพชร  POLYGON ((99.90442 16.68813, 99.89295 16.63188...
#
# [2960947 rows x 9 columns]

# %%
data_final[['name']] = data_final[['name']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data_finaldropped = data_final.dropna()

# %%
data_final_1= data_finaldropped[['announce_date','sex','age','risk','province_of_onset','จำนวนผู้ติดเชื้อ','6 ภูมิภาค (ภูมิศาสตร์)','geometry']]
data_final_1
# Out:
#         announce_date      sex   age                              risk  \
# 0           12/1/2020     หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020     หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020     หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020      ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           24/1/2020     หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...      ...   ...                               ...
# 2960941     18/3/2022  ไม่ระบุ  11.0                             อื่นๆ
# 2960943     18/3/2022  ไม่ระบุ  21.0                             อื่นๆ
# 2960944     18/3/2022  ไม่ระบุ  22.0                             อื่นๆ
# 2960945     18/3/2022  ไม่ระบุ  25.0                             อื่นๆ
# 2960946     18/3/2022  ไม่ระบุ  64.0                             อื่นๆ
#
#         province_of_onset  จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0           กรุงเทพมหานคร            571854                   กลาง
# 1           กรุงเทพมหานคร            571854                   กลาง
# 2                  นครปฐม             71629                   กลาง
# 3           กรุงเทพมหานคร            571854                   กลาง
# 4           กรุงเทพมหานคร            571854                   กลาง
# ...                   ...               ...                    ...
# 2960941        นครราชสีมา             14128     ตะวันออกเฉียงเหนือ
# 2960943     กรุงเทพมหานคร            571854                   กลาง
# 2960944     กรุงเทพมหานคร            571854                   กลาง
# 2960945     กรุงเทพมหานคร            571854                   กลาง
# 2960946         กำแพงเพชร             12908                   กลาง
#
#                                                   geometry
# 0        POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1        POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2        POLYGON ((100.28321 14.11622, 100.26368 14.029...
# 3        POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 4        POLYGON ((100.85537 13.69198, 100.71321 13.711...
# ...                                                    ...
# 2960941  POLYGON ((102.33167 15.80583, 102.36939 15.763...
# 2960943  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960944  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960945  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960946  POLYGON ((99.90442 16.68813, 99.89295 16.63188...
#
# [2805899 rows x 8 columns]

# %% [markdown]
# ## แบ่งข้อมูลไปใช้งาน

# %%
import datetime
df = pd.DataFrame(data_final_1)
df['announce_date'] = pd.to_datetime(df['announce_date'], format = "%d/%m/%Y")
df['year'] = df['announce_date'].dt.year
df['month'] = df['announce_date'].dt.month

# %%
df
# Out:
#         announce_date      sex   age                              risk  \
# 0          2020-01-12     หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2020-01-17     หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          2020-01-22     หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          2020-01-22      ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          2020-01-24     หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...      ...   ...                               ...
# 2960941    2022-03-18  ไม่ระบุ  11.0                             อื่นๆ
# 2960943    2022-03-18  ไม่ระบุ  21.0                             อื่นๆ
# 2960944    2022-03-18  ไม่ระบุ  22.0                             อื่นๆ
# 2960945    2022-03-18  ไม่ระบุ  25.0                             อื่นๆ
# 2960946    2022-03-18  ไม่ระบุ  64.0                             อื่นๆ
#
#         province_of_onset  จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0           กรุงเทพมหานคร            571854                   กลาง
# 1           กรุงเทพมหานคร            571854                   กลาง
# 2                  นครปฐม             71629                   กลาง
# 3           กรุงเทพมหานคร            571854                   กลาง
# 4           กรุงเทพมหานคร            571854                   กลาง
# ...                   ...               ...                    ...
# 2960941        นครราชสีมา             14128     ตะวันออกเฉียงเหนือ
# 2960943     กรุงเทพมหานคร            571854                   กลาง
# 2960944     กรุงเทพมหานคร            571854                   กลาง
# 2960945     กรุงเทพมหานคร            571854                   กลาง
# 2960946         กำแพงเพชร             12908                   กลาง
#
#                                                   geometry  year  month
# 0        POLYGON ((100.85537 13.69198, 100.71321 13.711...  2020      1
# 1        POLYGON ((100.85537 13.69198, 100.71321 13.711...  2020      1
# 2        POLYGON ((100.28321 14.11622, 100.26368 14.029...  2020      1
# 3        POLYGON ((100.85537 13.69198, 100.71321 13.711...  2020      1
# 4        POLYGON ((100.85537 13.69198, 100.71321 13.711...  2020      1
# ...                                                    ...   ...    ...
# 2960941  POLYGON ((102.33167 15.80583, 102.36939 15.763...  2022      3
# 2960943  POLYGON ((100.85537 13.69198, 100.71321 13.711...  2022      3
# 2960944  POLYGON ((100.85537 13.69198, 100.71321 13.711...  2022      3
# 2960945  POLYGON ((100.85537 13.69198, 100.71321 13.711...  2022      3
# 2960946  POLYGON ((99.90442 16.68813, 99.89295 16.63188...  2022      3
#
# [2805899 rows x 10 columns]

# %%
df_1= df[['announce_date','year','month','sex','age','risk','province_of_onset','จำนวนผู้ติดเชื้อ','6 ภูมิภาค (ภูมิศาสตร์)','geometry']]
df_1
# Out:
#         announce_date  year  month      sex   age  \
# 0          2020-01-12  2020      1     หญิง  61.0
# 1          2020-01-17  2020      1     หญิง  74.0
# 2          2020-01-22  2020      1     หญิง  73.0
# 3          2020-01-22  2020      1      ชาย  68.0
# 4          2020-01-24  2020      1     หญิง  66.0
# ...               ...   ...    ...      ...   ...
# 2960941    2022-03-18  2022      3  ไม่ระบุ  11.0
# 2960943    2022-03-18  2022      3  ไม่ระบุ  21.0
# 2960944    2022-03-18  2022      3  ไม่ระบุ  22.0
# 2960945    2022-03-18  2022      3  ไม่ระบุ  25.0
# 2960946    2022-03-18  2022      3  ไม่ระบุ  64.0
#
#                                      risk province_of_onset  จำนวนผู้ติดเชื้อ  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม             71629
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            571854
# ...                                   ...               ...               ...
# 2960941                             อื่นๆ        นครราชสีมา             14128
# 2960943                             อื่นๆ     กรุงเทพมหานคร            571854
# 2960944                             อื่นๆ     กรุงเทพมหานคร            571854
# 2960945                             อื่นๆ     กรุงเทพมหานคร            571854
# 2960946                             อื่นๆ         กำแพงเพชร             12908
#
#         6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                         กลาง
# 1                         กลาง
# 2                         กลาง
# 3                         กลาง
# 4                         กลาง
# ...                        ...
# 2960941     ตะวันออกเฉียงเหนือ
# 2960943                   กลาง
# 2960944                   กลาง
# 2960945                   กลาง
# 2960946                   กลาง
#
#                                                   geometry
# 0        POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1        POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2        POLYGON ((100.28321 14.11622, 100.26368 14.029...
# 3        POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 4        POLYGON ((100.85537 13.69198, 100.71321 13.711...
# ...                                                    ...
# 2960941  POLYGON ((102.33167 15.80583, 102.36939 15.763...
# 2960943  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960944  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960945  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960946  POLYGON ((99.90442 16.68813, 99.89295 16.63188...
#
# [2805899 rows x 10 columns]

# %%
data_final_2020 = df_1[((df_1['month'] >= 1) & (df_1['month'] <= 12)) & (df_1['year'] == 2020)]
data_final_2020
# Out:
#      announce_date  year  month   sex   age                              risk  \
# 0       2020-01-12  2020      1  หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       2020-01-17  2020      1  หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       2020-01-22  2020      1  หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       2020-01-22  2020      1   ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       2020-01-24  2020      1  หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...            ...   ...    ...   ...   ...                               ...
# 6907    2020-12-31  2020     12  หญิง  39.0                     Cluster ระยอง
# 6908    2020-12-31  2020     12   ชาย  54.0                     Cluster ระยอง
# 6909    2020-12-31  2020     12   ชาย  54.0                     Cluster ระยอง
# 6910    2020-12-31  2020     12   ชาย  56.0                     Cluster ระยอง
# 6911    2020-12-31  2020     12   ชาย  70.0                     Cluster ระยอง
#
#      province_of_onset  จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0        กรุงเทพมหานคร            571854                   กลาง
# 1        กรุงเทพมหานคร            571854                   กลาง
# 2               นครปฐม             71629                   กลาง
# 3        กรุงเทพมหานคร            571854                   กลาง
# 4        กรุงเทพมหานคร            571854                   กลาง
# ...                ...               ...                    ...
# 6907             ระยอง             75034               ตะวันออก
# 6908             ระยอง             75034               ตะวันออก
# 6909             ระยอง             75034               ตะวันออก
# 6910             ระยอง             75034               ตะวันออก
# 6911             ระยอง             75034               ตะวันออก
#
#                                                geometry
# 0     POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1     POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2     POLYGON ((100.28321 14.11622, 100.26368 14.029...
# 3     POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 4     POLYGON ((100.85537 13.69198, 100.71321 13.711...
# ...                                                 ...
# 6907  POLYGON ((101.69264 13.13398, 101.71331 13.034...
# 6908  POLYGON ((101.69264 13.13398, 101.71331 13.034...
# 6909  POLYGON ((101.69264 13.13398, 101.71331 13.034...
# 6910  POLYGON ((101.69264 13.13398, 101.71331 13.034...
# 6911  POLYGON ((101.69264 13.13398, 101.71331 13.034...
#
# [6830 rows x 10 columns]

# %%
data_final_2021_1 = df_1[((df_1['month'] == 1) | (df_1['month'] == 2) | (df_1['month'] == 3) | (df_1['month'] == 4) | (df_1['month'] == 5)| (df_1['month'] == 6)) & (df_1['year'] == 2021)]
data_final_2021_1
# Out:
#        announce_date  year  month   sex   age                 risk  \
# 125       2021-03-06  2021      3  หญิง  55.0  Cluster ตลาดพรพัฒน์
# 6912      2021-01-01  2021      1  หญิง  40.0    Cluster สมุทรสาคร
# 6913      2021-01-01  2021      1  หญิง  21.0        Cluster ระยอง
# 6914      2021-01-01  2021      1  หญิง  20.0          สถานบันเทิง
# 6915      2021-01-01  2021      1  หญิง  47.0    Cluster สมุทรสาคร
# ...              ...   ...    ...   ...   ...                  ...
# 259746    2021-06-30  2021      6  หญิง  62.0     ทัณฑสถาน/เรือนจำ
# 259747    2021-06-30  2021      6  หญิง  63.0     ทัณฑสถาน/เรือนจำ
# 259748    2021-06-30  2021      6  หญิง  34.0     ทัณฑสถาน/เรือนจำ
# 259749    2021-06-30  2021      6  หญิง  45.0     ทัณฑสถาน/เรือนจำ
# 259750    2021-06-30  2021      6   ชาย  37.0     ทัณฑสถาน/เรือนจำ
#
#        province_of_onset  จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 125             ปทุมธานี             85833                   กลาง
# 6912            ปทุมธานี             85833                   กลาง
# 6913            ปทุมธานี             85833                   กลาง
# 6914              นครปฐม             71629                   กลาง
# 6915              นครปฐม             71629                   กลาง
# ...                  ...               ...                    ...
# 259746             สงขลา             77183                    ใต้
# 259747             สงขลา             77183                    ใต้
# 259748             สงขลา             77183                    ใต้
# 259749             สงขลา             77183                    ใต้
# 259750             สงขลา             77183                    ใต้
#
#                                                  geometry
# 125     POLYGON ((100.91242 14.21391, 100.90529 13.955...
# 6912    POLYGON ((100.91242 14.21391, 100.90529 13.955...
# 6913    POLYGON ((100.91242 14.21391, 100.90529 13.955...
# 6914    POLYGON ((100.28321 14.11622, 100.26368 14.029...
# 6915    POLYGON ((100.28321 14.11622, 100.26368 14.029...
# ...                                                   ...
# 259746  MULTIPOLYGON (((100.19920 6.69941, 100.20983 6...
# 259747  MULTIPOLYGON (((100.19920 6.69941, 100.20983 6...
# 259748  MULTIPOLYGON (((100.19920 6.69941, 100.20983 6...
# 259749  MULTIPOLYGON (((100.19920 6.69941, 100.20983 6...
# 259750  MULTIPOLYGON (((100.19920 6.69941, 100.20983 6...
#
# [248082 rows x 10 columns]

# %%
data_final_2021_2 = df_1[((df_1['month'] == 7) | (df_1['month'] == 8) | (df_1['month'] == 9)) & (df_1['year'] == 2021)]
data_final_2021_2
# Out:
#         announce_date  year  month   sex   age  \
# 259767     2021-07-01  2021      7   ชาย  45.0
# 259768     2021-07-01  2021      7   ชาย  41.0
# 259769     2021-07-01  2021      7   ชาย  20.0
# 259770     2021-07-01  2021      7   ชาย  75.0
# 259771     2021-07-01  2021      7  หญิง  41.0
# ...               ...   ...    ...   ...   ...
# 1423794    2021-09-30  2021      9   ชาย  45.0
# 1423795    2021-09-30  2021      9  หญิง  57.0
# 1423796    2021-09-30  2021      9  หญิง  86.0
# 1423797    2021-09-30  2021      9   ชาย  82.0
# 1423798    2021-09-30  2021      9  หญิง  58.0
#
#                                                 risk province_of_onset  \
# 259767   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้         เชียงใหม่
# 259768                                         อื่นๆ         เชียงใหม่
# 259769                                         อื่นๆ         เชียงใหม่
# 259770                                         อื่นๆ         เชียงใหม่
# 259771                                         อื่นๆ             พะเยา
# ...                                              ...               ...
# 1423794                                        อื่นๆ        ฉะเชิงเทรา
# 1423795                                        อื่นๆ     กรุงเทพมหานคร
# 1423796                                        อื่นๆ     กรุงเทพมหานคร
# 1423797  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 1423798                                        อื่นๆ     กรุงเทพมหานคร
#
#          จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 259767              43291                  เหนือ
# 259768              43291                  เหนือ
# 259769              43291                  เหนือ
# 259770              43291                  เหนือ
# 259771               8324                  เหนือ
# ...                   ...                    ...
# 1423794             56140               ตะวันออก
# 1423795            571854                   กลาง
# 1423796            571854                   กลาง
# 1423797            571854                   กลาง
# 1423798            571854                   กลาง
#
#                                                   geometry
# 259767   POLYGON ((99.39986 18.99843, 99.37143 18.97538...
# 259768   POLYGON ((99.39986 18.99843, 99.37143 18.97538...
# 259769   POLYGON ((99.39986 18.99843, 99.37143 18.97538...
# 259770   POLYGON ((99.39986 18.99843, 99.37143 18.97538...
# 259771   POLYGON ((100.57476 19.50835, 100.59033 19.476...
# ...                                                    ...
# 1423794  POLYGON ((101.14083 13.96842, 101.15251 13.850...
# 1423795  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1423796  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1423797  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1423798  POLYGON ((100.85537 13.69198, 100.71321 13.711...
#
# [1154060 rows x 10 columns]

# %%
data_final_2021_3 = df_1[((df_1['month'] == 10) | (df_1['month'] == 11) | (df_1['month'] == 12)) & (df_1['year'] == 2021)]
data_final_2021_3
# Out:
#         announce_date  year  month   sex   age         risk province_of_onset  \
# 1423799    2021-10-01  2021     10  หญิง  30.0        อื่นๆ             พะเยา
# 1423800    2021-10-01  2021     10  หญิง  32.0        อื่นๆ             พะเยา
# 1423801    2021-10-01  2021     10   ชาย  18.0        อื่นๆ              น่าน
# 1423802    2021-10-01  2021     10  หญิง  13.0        อื่นๆ              น่าน
# 1423803    2021-10-01  2021     10   ชาย  31.0        อื่นๆ              น่าน
# ...               ...   ...    ...   ...   ...          ...               ...
# 1942831    2021-12-31  2021     12   ชาย  33.0  Test and Go     กรุงเทพมหานคร
# 1942832    2021-12-31  2021     12  หญิง  30.0  Test and Go     กรุงเทพมหานคร
# 1942833    2021-12-31  2021     12   ชาย  43.0  Test and Go     กรุงเทพมหานคร
# 1942834    2021-12-31  2021     12  หญิง  30.0        อื่นๆ     กรุงเทพมหานคร
# 1942835    2021-12-31  2021     12  หญิง  18.0  Test and Go     กรุงเทพมหานคร
#
#          จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 1423799              8324                  เหนือ
# 1423800              8324                  เหนือ
# 1423801              7720                  เหนือ
# 1423802              7720                  เหนือ
# 1423803              7720                  เหนือ
# ...                   ...                    ...
# 1942831            571854                   กลาง
# 1942832            571854                   กลาง
# 1942833            571854                   กลาง
# 1942834            571854                   กลาง
# 1942835            571854                   กลาง
#
#                                                   geometry
# 1423799  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1423800  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1423801  POLYGON ((101.07409 18.37161, 100.91945 18.249...
# 1423802  POLYGON ((101.07409 18.37161, 100.91945 18.249...
# 1423803  POLYGON ((101.07409 18.37161, 100.91945 18.249...
# ...                                                    ...
# 1942831  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1942832  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1942833  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1942834  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 1942835  POLYGON ((100.85537 13.69198, 100.71321 13.711...
#
# [491590 rows x 10 columns]

# %%
data_final_2022= df_1[((df_1['month'] >= 1) & (df_1['month'] <= 3)) & (df_1['year'] == 2022)]
data_final_2022
# Out:
#         announce_date  year  month      sex   age  \
# 1942836    2022-01-01  2022      1      ชาย  39.0
# 1942837    2022-01-01  2022      1     หญิง  39.0
# 1942838    2022-01-01  2022      1      ชาย  64.0
# 1942839    2022-01-01  2022      1      ชาย  27.0
# 1942840    2022-01-01  2022      1     หญิง  35.0
# ...               ...   ...    ...      ...   ...
# 2960941    2022-03-18  2022      3  ไม่ระบุ  11.0
# 2960943    2022-03-18  2022      3  ไม่ระบุ  21.0
# 2960944    2022-03-18  2022      3  ไม่ระบุ  22.0
# 2960945    2022-03-18  2022      3  ไม่ระบุ  25.0
# 2960946    2022-03-18  2022      3  ไม่ระบุ  64.0
#
#                                                 risk province_of_onset  \
# 1942836                                        อื่นๆ             พะเยา
# 1942837  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 1942838  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 1942839  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 1942840                         อยู่ระหว่างการสอบสวน             พะเยา
# ...                                              ...               ...
# 2960941                                        อื่นๆ        นครราชสีมา
# 2960943                                        อื่นๆ     กรุงเทพมหานคร
# 2960944                                        อื่นๆ     กรุงเทพมหานคร
# 2960945                                        อื่นๆ     กรุงเทพมหานคร
# 2960946                                        อื่นๆ         กำแพงเพชร
#
#          จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 1942836              8324                  เหนือ
# 1942837              8324                  เหนือ
# 1942838              8324                  เหนือ
# 1942839              8324                  เหนือ
# 1942840              8324                  เหนือ
# ...                   ...                    ...
# 2960941             14128     ตะวันออกเฉียงเหนือ
# 2960943            571854                   กลาง
# 2960944            571854                   กลาง
# 2960945            571854                   กลาง
# 2960946             12908                   กลาง
#
#                                                   geometry
# 1942836  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1942837  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1942838  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1942839  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1942840  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# ...                                                    ...
# 2960941  POLYGON ((102.33167 15.80583, 102.36939 15.763...
# 2960943  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960944  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960945  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960946  POLYGON ((99.90442 16.68813, 99.89295 16.63188...
#
# [905337 rows x 10 columns]

# %%
data_Jan= df_1[((df_1['month'] == 1) & (df_1['month'] == 1)) & (df_1['year'] == 2022)]
data_Jan
# Out:
#         announce_date  year  month   sex   age  \
# 1942836    2022-01-01  2022      1   ชาย  39.0
# 1942837    2022-01-01  2022      1  หญิง  39.0
# 1942838    2022-01-01  2022      1   ชาย  64.0
# 1942839    2022-01-01  2022      1   ชาย  27.0
# 1942840    2022-01-01  2022      1  หญิง  35.0
# ...               ...   ...    ...   ...   ...
# 2144731    2022-01-31  2022      1   ชาย  40.0
# 2144732    2022-01-31  2022      1  หญิง   7.0
# 2144733    2022-01-31  2022      1  หญิง  35.0
# 2144734    2022-01-31  2022      1   ชาย  40.0
# 2144735    2022-01-31  2022      1   ชาย  48.0
#
#                                                   risk province_of_onset  \
# 1942836                                          อื่นๆ             พะเยา
# 1942837    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 1942838    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 1942839    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 1942840                           อยู่ระหว่างการสอบสวน             พะเยา
# ...                                                ...               ...
# 2144731    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 2144732    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 2144733                                          อื่นๆ     กรุงเทพมหานคร
# 2144734  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว           นนทบุรี
# 2144735    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          ปทุมธานี
#
#          จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 1942836              8324                  เหนือ
# 1942837              8324                  เหนือ
# 1942838              8324                  เหนือ
# 1942839              8324                  เหนือ
# 1942840              8324                  เหนือ
# ...                   ...                    ...
# 2144731            571854                   กลาง
# 2144732            571854                   กลาง
# 2144733            571854                   กลาง
# 2144734            118332                   กลาง
# 2144735             85833                   กลาง
#
#                                                   geometry
# 1942836  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1942837  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1942838  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1942839  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 1942840  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# ...                                                    ...
# 2144731  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2144732  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2144733  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2144734  POLYGON ((100.35029 14.11371, 100.33659 14.060...
# 2144735  POLYGON ((100.91242 14.21391, 100.90529 13.955...
#
# [177813 rows x 10 columns]

# %%
#data_Jan.to_csv(os.path.join(path,'data_Jan.csv'))

# %%
data_Feb= df_1[((df_1['month'] == 2) & (df_1['month'] == 2)) & (df_1['year'] == 2022)]
data_Feb
# Out:
#         announce_date  year  month   sex   age  \
# 2144736    2022-02-01  2022      2  หญิง  35.0
# 2144737    2022-02-01  2022      2  หญิง  19.0
# 2144738    2022-02-01  2022      2  หญิง   8.0
# 2144739    2022-02-01  2022      2  หญิง  44.0
# 2144740    2022-02-01  2022      2   ชาย  44.0
# ...               ...   ...    ...   ...   ...
# 2571067    2022-02-28  2022      2  หญิง  52.0
# 2571068    2022-02-28  2022      2   ชาย  12.0
# 2571069    2022-02-28  2022      2  หญิง  16.0
# 2571070    2022-02-28  2022      2  หญิง  37.0
# 2571071    2022-02-28  2022      2  หญิง  40.0
#
#                                                 risk province_of_onset  \
# 2144736                                        อื่นๆ             พะเยา
# 2144737  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2144738  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2144739  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2144740  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...                                              ...               ...
# 2571067                                        อื่นๆ     กรุงเทพมหานคร
# 2571068                                        อื่นๆ     กรุงเทพมหานคร
# 2571069                                        อื่นๆ     กรุงเทพมหานคร
# 2571070                                        อื่นๆ     กรุงเทพมหานคร
# 2571071                                        อื่นๆ     กรุงเทพมหานคร
#
#          จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 2144736              8324                  เหนือ
# 2144737              8324                  เหนือ
# 2144738              8324                  เหนือ
# 2144739              8324                  เหนือ
# 2144740              8324                  เหนือ
# ...                   ...                    ...
# 2571067            571854                   กลาง
# 2571068            571854                   กลาง
# 2571069            571854                   กลาง
# 2571070            571854                   กลาง
# 2571071            571854                   กลาง
#
#                                                   geometry
# 2144736  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2144737  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2144738  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2144739  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2144740  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# ...                                                    ...
# 2571067  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2571068  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2571069  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2571070  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2571071  POLYGON ((100.85537 13.69198, 100.71321 13.711...
#
# [378180 rows x 10 columns]

# %%
#data_Feb.to_csv(os.path.join(path,'data_Feb.csv'))

# %%
data_Mar= df_1[((df_1['month'] == 3) & (df_1['month'] == 3)) & (df_1['year'] == 2022)]
data_Mar
# Out:
#         announce_date  year  month      sex   age  \
# 2571072    2022-03-01  2022      3     หญิง  47.0
# 2571073    2022-03-01  2022      3     หญิง  34.0
# 2571074    2022-03-01  2022      3     หญิง  11.0
# 2571075    2022-03-01  2022      3     หญิง  20.0
# 2571076    2022-03-01  2022      3     หญิง  16.0
# ...               ...   ...    ...      ...   ...
# 2960941    2022-03-18  2022      3  ไม่ระบุ  11.0
# 2960943    2022-03-18  2022      3  ไม่ระบุ  21.0
# 2960944    2022-03-18  2022      3  ไม่ระบุ  22.0
# 2960945    2022-03-18  2022      3  ไม่ระบุ  25.0
# 2960946    2022-03-18  2022      3  ไม่ระบุ  64.0
#
#                                                 risk province_of_onset  \
# 2571072                                        อื่นๆ           สุโขทัย
# 2571073                                        อื่นๆ           สุโขทัย
# 2571074                                        อื่นๆ           สุโขทัย
# 2571075  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้           สุโขทัย
# 2571076                                        อื่นๆ           สุโขทัย
# ...                                              ...               ...
# 2960941                                        อื่นๆ        นครราชสีมา
# 2960943                                        อื่นๆ     กรุงเทพมหานคร
# 2960944                                        อื่นๆ     กรุงเทพมหานคร
# 2960945                                        อื่นๆ     กรุงเทพมหานคร
# 2960946                                        อื่นๆ         กำแพงเพชร
#
#          จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 2571072             11520                   กลาง
# 2571073             11520                   กลาง
# 2571074             11520                   กลาง
# 2571075             11520                   กลาง
# 2571076             11520                   กลาง
# ...                   ...                    ...
# 2960941             14128     ตะวันออกเฉียงเหนือ
# 2960943            571854                   กลาง
# 2960944            571854                   กลาง
# 2960945            571854                   กลาง
# 2960946             12908                   กลาง
#
#                                                   geometry
# 2571072  POLYGON ((99.89657 17.80369, 99.97708 17.67564...
# 2571073  POLYGON ((99.89657 17.80369, 99.97708 17.67564...
# 2571074  POLYGON ((99.89657 17.80369, 99.97708 17.67564...
# 2571075  POLYGON ((99.89657 17.80369, 99.97708 17.67564...
# 2571076  POLYGON ((99.89657 17.80369, 99.97708 17.67564...
# ...                                                    ...
# 2960941  POLYGON ((102.33167 15.80583, 102.36939 15.763...
# 2960943  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960944  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960945  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960946  POLYGON ((99.90442 16.68813, 99.89295 16.63188...
#
# [349344 rows x 10 columns]

# %%
data_Mar_1 = data_Mar[(data_Mar['announce_date'] >= '2022-03-17') & (data_Mar['announce_date'] <= '2022-03-18')]     # เลือกข้อมูล เดือน 8 ปี 2021
data_Mar_1
# Out:
#         announce_date  year  month      sex   age  \
# 2910600    2022-03-17  2022      3     หญิง  69.0
# 2910601    2022-03-17  2022      3      ชาย  32.0
# 2910602    2022-03-17  2022      3      ชาย  41.0
# 2910603    2022-03-17  2022      3     หญิง  42.0
# 2910604    2022-03-17  2022      3     หญิง  56.0
# ...               ...   ...    ...      ...   ...
# 2960941    2022-03-18  2022      3  ไม่ระบุ  11.0
# 2960943    2022-03-18  2022      3  ไม่ระบุ  21.0
# 2960944    2022-03-18  2022      3  ไม่ระบุ  22.0
# 2960945    2022-03-18  2022      3  ไม่ระบุ  25.0
# 2960946    2022-03-18  2022      3  ไม่ระบุ  64.0
#
#                                                 risk province_of_onset  \
# 2910600  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2910601  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2910602  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2910603  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2910604  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...                                              ...               ...
# 2960941                                        อื่นๆ        นครราชสีมา
# 2960943                                        อื่นๆ     กรุงเทพมหานคร
# 2960944                                        อื่นๆ     กรุงเทพมหานคร
# 2960945                                        อื่นๆ     กรุงเทพมหานคร
# 2960946                                        อื่นๆ         กำแพงเพชร
#
#          จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 2910600              8324                  เหนือ
# 2910601              8324                  เหนือ
# 2910602              8324                  เหนือ
# 2910603              8324                  เหนือ
# 2910604              8324                  เหนือ
# ...                   ...                    ...
# 2960941             14128     ตะวันออกเฉียงเหนือ
# 2960943            571854                   กลาง
# 2960944            571854                   กลาง
# 2960945            571854                   กลาง
# 2960946             12908                   กลาง
#
#                                                   geometry
# 2910600  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2910601  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2910602  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2910603  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2910604  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# ...                                                    ...
# 2960941  POLYGON ((102.33167 15.80583, 102.36939 15.763...
# 2960943  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960944  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960945  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2960946  POLYGON ((99.90442 16.68813, 99.89295 16.63188...
#
# [45155 rows x 10 columns]

# %%
data_Mar_1.to_csv(os.path.join(path,'data_Mar_1.csv'))

# %%
data_Mar_2 = data_Mar[(data_Mar['announce_date'] >= '2022-03-15') & (data_Mar['announce_date'] <= '2022-03-16')]     # เลือกข้อมูล เดือน 8 ปี 2021
data_Mar_2
# Out:
#         announce_date  year  month      sex   age  \
# 2869252    2022-03-15  2022      3     หญิง  21.0
# 2869253    2022-03-15  2022      3     หญิง  34.0
# 2869254    2022-03-15  2022      3      ชาย  22.0
# 2869255    2022-03-15  2022      3     หญิง  63.0
# 2869256    2022-03-15  2022      3      ชาย  59.0
# ...               ...   ...    ...      ...   ...
# 2910595    2022-03-16  2022      3  ไม่ระบุ  33.0
# 2910596    2022-03-16  2022      3  ไม่ระบุ  85.0
# 2910597    2022-03-16  2022      3  ไม่ระบุ  59.0
# 2910598    2022-03-16  2022      3     หญิง  53.0
# 2910599    2022-03-16  2022      3  ไม่ระบุ  16.0
#
#                                                 risk province_of_onset  \
# 2869252  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2869253  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2869254  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2869255  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2869256  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...                                              ...               ...
# 2910595                                        อื่นๆ   พระนครศรีอยุธยา
# 2910596                                        อื่นๆ     กรุงเทพมหานคร
# 2910597                                        อื่นๆ        นครราชสีมา
# 2910598              บุคลากรด้านการแพทย์และสาธารณสุข     กรุงเทพมหานคร
# 2910599                                        อื่นๆ     กรุงเทพมหานคร
#
#          จำนวนผู้ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์)  \
# 2869252              8324                  เหนือ
# 2869253              8324                  เหนือ
# 2869254              8324                  เหนือ
# 2869255              8324                  เหนือ
# 2869256              8324                  เหนือ
# ...                   ...                    ...
# 2910595             55375                   กลาง
# 2910596            571854                   กลาง
# 2910597             14128     ตะวันออกเฉียงเหนือ
# 2910598            571854                   กลาง
# 2910599            571854                   กลาง
#
#                                                   geometry
# 2869252  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2869253  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2869254  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2869255  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# 2869256  POLYGON ((100.57476 19.50835, 100.59033 19.476...
# ...                                                    ...
# 2910595  POLYGON ((100.59405 14.65593, 100.57436 14.589...
# 2910596  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2910597  POLYGON ((102.33167 15.80583, 102.36939 15.763...
# 2910598  POLYGON ((100.85537 13.69198, 100.71321 13.711...
# 2910599  POLYGON ((100.85537 13.69198, 100.71321 13.711...
#
# [36835 rows x 10 columns]

# %%
data_Mar_2.to_csv(os.path.join(path,'data_Mar_2.csv'))

# %%
#data_Mar.to_csv(os.path.join(path,'data_Mar.csv'))

# %% [markdown]
# ## โหลดข้อมูลออกไปใช้งาน

# %%
#data_final_2020.to_csv(os.path.join(path,'data_final_2020.csv'))

# %%
#data_final_2021_1.to_csv(os.path.join(path,'data_final_2021_1.csv'))

# %%
#data_final_2021_2.to_csv(os.path.join(path,'data_final_2021_2.csv'))

# %%
#data_final_2021_3.to_csv(os.path.join(path,'data_final_2021_3.csv'))

# %%
#data_final_2022.to_csv(os.path.join(path,'data_final_2022.csv'))

# %%
# data_final_1.to_csv(os.path.join(path,'data_final_1.csv'))

# %%
#df.to_csv(os.path.join(path,'df.csv'))
